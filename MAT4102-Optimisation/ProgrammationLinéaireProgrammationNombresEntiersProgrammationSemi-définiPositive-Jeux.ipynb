# %% [markdown]
# $$\mbox{Cours optimisation (IG2) : travaux pratiques}$$
# $$\mbox{Programmation Linéaire, Programmation en Nombres Entiers, Programmation Semi-définie Positive, Jeux}$$

# %% [markdown]
# We are going to use Julia. There are different options to do that.
# - You can install Julia on your computer (you might need an editor such as atom) and execute evrything locally. You can just copy some parts of the code given in the html file.
# - In addition to that, you can also install jupyter on your machine and then open the file *.ipynb
# - Use google colab, in this case, you need to have a google account (and you d'ont need to install Julia). The file is stored on the Google drive, and programs are executed on a virtual machine.  You have to open the *.ipynb and run the installation cell below.

# %%
# Installation cell
%%capture
%%shell
if ! command -v julia 3>&1 > /dev/null
then
    wget -q 'https://julialang-s3.julialang.org/bin/linux/x64/1.7/julia-1.7.2-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add IJulia; precompile;"'
echo 'Done'

# %% [markdown]
# After you run the first cell (the cell directly above this text), go to Colab's menu bar and select **Edit** and select **Notebook settings** from the drop down. Select *Julia 1.7* in Runtime type. You can also select your prefered harwdware acceleration (defaults to GPU).
#
# <br/>You should see something like this:
#
# > ![Colab Img](https://raw.githubusercontent.com/Dsantra92/Julia-on-Colab/master/misc/julia_menu.png)
#
# <br/>Click on SAVE
# <br/>**We are ready to get going**

# %%
VERSION
# Out:
# v"1.8.5"

# %% [markdown]
# # Attaques et mesures de sécurité

# %% [markdown]
# Un opérateur ou un administrateur d'un réseau informatique dispose d'une panoplie de mesures de sécurité qu'il pourrait mettre en place pour se protéger contre les attaques informatiques. Imaginons que $N_m$ mesures numérotées $1, ..., N_m$ sont disponibles. Comme la mise en place de trop de mesures induit des surcoûts (financiers, détérioration du service, etc.), l'opérateur devrait choisir $k_m$ mesures parmi ces $N_m$ en essayant de minimiser l'impact des attaques qu'il pourrait ne pas détecter. Une entité malveillante cherche justement à attaquer le réseau et dispose d'une panoplie d'attaques. Disons que $N_a$ attaques sont possibles et que l'attaquant compte en sélectionner $k_a$ attaques en tentant de maximiser l'impact de ses attaques. Utilisons le vecteur $x$ de taille $N_m$ pour identifier les mesures mises en place ($x_i = 1$ si la mesure $i$ est mise en place et $0$ sinon). Si une attaque du type $j$ est lancée, on peut  estimer que la probabilité pour que la mesure de sécurité $i$ permette de l'intercepter est égale à $p_{i,j}$. En faisant une hypothèse d'indépendence, l'attaque $j$ n'est pas interceptée avec la probabilité $p_j = \prod_{i = 1}^{N_m} (1 - x_i p_{i j})$. On estime que l'impact de l'attaque $j$ s'exprime sous la forme de $w_j \log{p_j}$. Ainsi, d'une part il croît avec la probabilité de non-interception $p_j$. D'autre part, il dépend de $j$ à travers le terme $w_j$. Enfin, il s'exprime sous la forme de $\sum_{i = 1}^{N_m} x_i w_j \log{(1 - p_{i j})}$ qu'on pourra écrire comme $\sum_{i = 1}^{N_m} x_i w_{i j}$. Si on utilise le vecteur $y$ de taille $N_a$ pour identifier les attaques, l'objectif de l'attaquant est donc de maximiser $\sum_{i =1}^{N_m} \sum_{j = 1}^{N_a} x_i y_j w_{i j}$ alors que le défenseur cherche à minimiser cette quantité. Ainsi nous obtenons ici ce qu'on appelle  $\underline{\mbox{un jeu à somme nulle}}$.

# %% [markdown]
# Supposons que l'adminstrateur choisit ses $k_m$ mesures, et ensuite l'attaquant (qui a la possibilité de prendre connaissance des mesures déployées) choisit ses $k_a$ attaques (on a ici ce qu'on appelle un jeu du type Stackelberg avec un "leader" et un "follower"). Ainsi, l'objectif de l'opérateur est de résoudre le problème suivant :
# \begin{equation}
# \min_{x \in \{0,1\}^{N_m} \\ \sum_{i} x_i = k_m} \max_{y \in \{0,1\}^{N_a} \\ \sum_{j} y_j = k_a} \sum_{i = 1}^{N_m}  \sum_{j = 1}^{N_a}   x_i y_j w_{i j}
# \end{equation}

# %% [markdown]
# ## Question 1
# En remarquant que le problème intérieur (le max) peut être remplacé par un programme linéaire (c'est à dire que l'on peut relacher les contraintes d'intégrité), démontrez qu'il est possible d'exprimer le problème de l'opérateur comme suit :
#
# \begin{equation}
# \begin{array}{ll}
# & \min k_a \gamma + \sum_{j = 1}^{N_a} \pi_j \\
# & x_i \in \{0,1\}, \forall i \in \{1, ..., N_m \} \\
# & \sum_{i = 1}^{N_m} x_i = k_m \\
# & \pi_j \geq 0, \forall j \in \{1, ..., N_a \} \\
# & \pi_j + \gamma \geq \sum_{i = 1}^{N_m} x_i w_{i j}, \forall j \in \{1, ..., N_a \} \\
# & \gamma \in R
# \end{array}
# \end{equation}

# %% [markdown]
# La fonction suivante permet d'implémenter le MIP précédent.  Le résultat obtenu pour une matrice particulière W est donné.

# %%
import Pkg
Pkg.add("JuMP")
Pkg.add("GLPK")
using JuMP
using GLPK

function min_max_int(w, n1 ,k1 , n2, k2)

model=Model(GLPK.Optimizer)

@variable(model, x[1:n1], Bin)

@variable(model, gamma)

@variable(model, pi[1:n2]>=0)

@constraint(model,somme, sum(x[i] for i in 1:n1) ==k1)

@constraint(model,contrainte[j in 1:n2],pi[j] - sum(w[i,j]*x[i] for i in 1:n1)+ gamma>=0)

@objective(model, Min, sum(pi[j] for j in 1:n2) + k2*gamma)

print(model)

optimize!(model)
    
println("Solution optimale : ")
    
for i in 1:n1
    println(" x[", i, "] = ",  value(x[i]))
 end
        
return objective_value(model)
end
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed IrrationalConstants ── v0.1.1
#    Installed DiffRules ──────────── v1.12.2
#    Installed Bzip2_jll ──────────── v1.0.8+0
#    Installed CodecBzip2 ─────────── v0.7.2
#    Installed DiffResults ────────── v1.1.0
#    Installed BenchmarkTools ─────── v1.3.2
#    Installed MutableArithmetics ─── v1.1.0
#    Installed SpecialFunctions ───── v2.1.7
# ERROR: Data Error : jl_9jVPfIlEimF4~
#    Installed StaticArraysCore ───── v1.4.0
#    Installed NaNMath ────────────── v1.0.1
#    Installed OrderedCollections ─── v1.4.1
#    Installed TranscodingStreams ─── v0.9.11
#    Installed StaticArrays ───────── v1.5.12
#    Installed ForwardDiff ────────── v0.10.34
#    Installed ChainRulesCore ─────── v1.15.6
# ┌ Warning: failed to extract archive downloaded from https://pkg.julialang.org/package/4076af6c-e467-56ae-b986-b466b2749572/821341783388cd26bbb9bab4ad9d0992e78259a4
# └ @ Pkg.Operations /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.7/Pkg/src/Operations.jl:497
#    Installed Compat ─────────────── v4.5.0
#    Installed CommonSubexpressions ─ v0.3.0
#    Installed LogExpFunctions ────── v0.3.19
#    Installed DataStructures ─────── v0.18.13
#    Installed MacroTools ─────────── v0.5.10
#    Installed OpenSpecFun_jll ────── v0.5.5+0
#    Installed InverseFunctions ───── v0.1.8
#    Installed CodecZlib ──────────── v0.7.0
#    Installed ChangesOfVariables ─── v0.1.4
#    Installed MathOptInterface ───── v1.11.4
#    Installed DocStringExtensions ── v0.9.3
#    Installed JuMP ───────────────── v1.6.0
#     Updating `~/.julia/environments/v1.7/Project.toml`
#   [4076af6c] + JuMP v1.6.0
#     Updating `~/.julia/environments/v1.7/Manifest.toml`
#   [6e4b80f9] + BenchmarkTools v1.3.2
#   [d360d2e6] + ChainRulesCore v1.15.6
#   [9e997f8a] + ChangesOfVariables v0.1.4
#   [523fee87] + CodecBzip2 v0.7.2
#   [944b1d66] + CodecZlib v0.7.0
#   [bbf7d656] + CommonSubexpressions v0.3.0
#   [34da2185] + Compat v4.5.0
#   [864edb3b] + DataStructures v0.18.13
#   [163ba53b] + DiffResults v1.1.0
#   [b552c78f] + DiffRules v1.12.2
#   [ffbed154] + DocStringExtensions v0.9.3
#   [f6369f11] + ForwardDiff v0.10.34
#   [3587e190] + InverseFunctions v0.1.8
#   [92d709cd] + IrrationalConstants v0.1.1
#   [4076af6c] + JuMP v1.6.0
#   [2ab3a3ac] + LogExpFunctions v0.3.19
#   [1914dd2f] + MacroTools v0.5.10
#   [b8f27783] + MathOptInterface v1.11.4
#   [d8a4904e] + MutableArithmetics v1.1.0
#   [77ba4419] + NaNMath v1.0.1
#   [bac558e1] + OrderedCollections v1.4.1
#   [276daf66] + SpecialFunctions v2.1.7
#   [90137ffa] + StaticArrays v1.5.12
#   [1e83bf80] + StaticArraysCore v1.4.0
#   [3bb67fe8] + TranscodingStreams v0.9.11
#   [6e34b625] + Bzip2_jll v1.0.8+0
#   [efe28fd5] + OpenSpecFun_jll v0.5.5+0
#   [37e2e46d] + LinearAlgebra
#   [9abbd945] + Profile
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics
#   [e66e0078] + CompilerSupportLibraries_jll
#   [4536629a] + OpenBLAS_jll
#   [05823500] + OpenLibm_jll
#   [8e850b90] + libblastrampoline_jll
# Precompiling project...
#   ✓ OpenLibm_jll
#   ✓ OrderedCollections
#   ✓ Compat
#   ✓ InverseFunctions
#   ✓ DocStringExtensions
#   ✓ CompilerSupportLibraries_jll
#   ✓ IrrationalConstants
#   ✓ StaticArraysCore
#   ✓ TranscodingStreams
#   ✓ Bzip2_jll
#   ✓ MacroTools
#   ✓ NaNMath
#   ✓ BenchmarkTools
#   ✓ ChainRulesCore
#   ✓ OpenBLAS_jll
#   ✓ OpenSpecFun_jll
#   ✓ DataStructures
#   ✓ MutableArithmetics
#   ✓ DiffResults
#   ✓ CodecZlib
#   ✓ CodecBzip2
#   ✓ CommonSubexpressions
#   ✓ ChangesOfVariables
#   ✓ libblastrampoline_jll
#   ✓ LogExpFunctions
#   ✓ StaticArrays
#   ✓ SpecialFunctions
#   ✓ DiffRules
#   ✓ ForwardDiff
#   ✓ MathOptInterface
#   ✓ JuMP
#   31 dependencies successfully precompiled in 76 seconds (16 already precompiled)
#    Resolving package versions...
#    Installed GLPK_jll ─ v5.0.1+0
#    Installed GLPK ───── v1.1.0
#     Updating `~/.julia/environments/v1.7/Project.toml`
#   [60bf3e95] + GLPK v1.1.0
#     Updating `~/.julia/environments/v1.7/Manifest.toml`
#   [60bf3e95] + GLPK v1.1.0
#   [e8aa6df9] + GLPK_jll v5.0.1+0
#   [781609d7] + GMP_jll
# Precompiling project...
#   ✓ GMP_jll
#   ✓ GLPK_jll
#   ✓ GLPK
#   3 dependencies successfully precompiled in 8 seconds (47 already precompiled)
# min_max_int (generic function with 1 method)

# %% [markdown]
# Pour tester, prenons les valeurs suivantes :

# %%
global Nm = 6
global Na = 8
global km = 3
global ka = 3
global W = zeros(Float64,Nm,Na)

W =[ -4.0   0.0  -9.0   -1.0   -2.0  -9.0  -4.0   -5.0   
 -10.0  -1.0  -7.0    0.0    0.0  -5.0  -6.0   -5.0
  -3.0  -9.0  -9.0   -5.0    0.0  -7.0  -3.0  -10.0
 -10.0   0.0  -4.0    0.0  -10.0  -7.0  -6.0   -2.0
  -9.0  -7.0  -8.0    0.0   -1.0  -6.0  -5.0    0.0
  -3.0  -3.0  -5.0  -10.0   -9.0  -1.0  -4.0   -8.0]
# Out:
# 6×8 Matrix{Float64}:
#   -4.0   0.0  -9.0   -1.0   -2.0  -9.0  -4.0   -5.0
#  -10.0  -1.0  -7.0    0.0    0.0  -5.0  -6.0   -5.0
#   -3.0  -9.0  -9.0   -5.0    0.0  -7.0  -3.0  -10.0
#  -10.0   0.0  -4.0    0.0  -10.0  -7.0  -6.0   -2.0
#   -9.0  -7.0  -8.0    0.0   -1.0  -6.0  -5.0    0.0
#   -3.0  -3.0  -5.0  -10.0   -9.0  -1.0  -4.0   -8.0

# %%
min_max_int(W, Nm ,km , Na , ka)
# Out:
# $$ \begin{aligned}
# \min\quad & pi_{1} + pi_{2} + pi_{3} + pi_{4} + pi_{5} + pi_{6} + pi_{7} + pi_{8} + 3 gamma\\
# \text{Subject to} \quad & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} = 3.0\\
#  & 4 x_{1} + 10 x_{2} + 3 x_{3} + 10 x_{4} + 9 x_{5} + 3 x_{6} + gamma + pi_{1} \geq 0.0\\
#  & x_{2} + 9 x_{3} + 7 x_{5} + 3 x_{6} + gamma + pi_{2} \geq 0.0\\
#  & 9 x_{1} + 7 x_{2} + 9 x_{3} + 4 x_{4} + 8 x_{5} + 5 x_{6} + gamma + pi_{3} \geq 0.0\\
#  & x_{1} + 5 x_{3} + 10 x_{6} + gamma + pi_{4} \geq 0.0\\
#  & 2 x_{1} + 10 x_{4} + x_{5} + 9 x_{6} + gamma + pi_{5} \geq 0.0\\
#  & 9 x_{1} + 5 x_{2} + 7 x_{3} + 7 x_{4} + 6 x_{5} + x_{6} + gamma + pi_{6} \geq 0.0\\
#  & 4 x_{1} + 6 x_{2} + 3 x_{3} + 6 x_{4} + 5 x_{5} + 4 x_{6} + gamma + pi_{7} \geq 0.0\\
#  & 5 x_{1} + 5 x_{2} + 10 x_{3} + 2 x_{4} + 8 x_{6} + gamma + pi_{8} \geq 0.0\\
#  & pi_{1} \geq 0.0\\
#  & pi_{2} \geq 0.0\\
#  & pi_{3} \geq 0.0\\
#  & pi_{4} \geq 0.0\\
#  & pi_{5} \geq 0.0\\
#  & pi_{6} \geq 0.0\\
#  & pi_{7} \geq 0.0\\
#  & pi_{8} \geq 0.0\\
#  & x_{1} \in \{0, 1\}\\
#  & x_{2} \in \{0, 1\}\\
#  & x_{3} \in \{0, 1\}\\
#  & x_{4} \in \{0, 1\}\\
#  & x_{5} \in \{0, 1\}\\
#  & x_{6} \in \{0, 1\}\\
# \end{aligned} $$
# Solution optimale :
#  x[1] = 0.0
#  x[2] = 0.0
#  x[3] = 1.0
#  x[4] = 1.0
#  x[5] = 0.0
#  x[6] = 1.0
# -40.00000000000001

# %% [markdown]
# Supposons maintenant que l'attaquant joue en premier en décidant des $k_a$ attaques qu'il doit mener et l'opérateur pourra réagir en choisissant les meilleures mesures de sécurité. Il s'agit donc de résoudre le problème suivant :
# \begin{equation}
# \max_{y \in \{0,1\}^{N_a} \\ \sum_{j} y_j = k_a}  \min_{x \in \{0,1\}^{N_m} \\ \sum_{i} x_i = k_m}  \sum_{i = 1}^{N_m}  \sum_{j = 1}^{N_a}   x_i y_j w_{i j}
# \end{equation}
# ## Question 2
# Montrez que le problème ci-dessus peut être résolu en utilisant la fonction précédemment implémentée (min_max_int). Plus précisément, l'objectif optimal est donné par (-1)*min_max_int(-W',Na,ka,Nm, km)

# %%
(-1)*min_max_int(-W',Na,ka,Nm, km)
# Out:
# $$ \begin{aligned}
# \min\quad & pi_{1} + pi_{2} + pi_{3} + pi_{4} + pi_{5} + pi_{6} + 3 gamma\\
# \text{Subject to} \quad & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} + x_{7} + x_{8} = 3.0\\
#  & -4 x_{1} - 9 x_{3} - x_{4} - 2 x_{5} - 9 x_{6} - 4 x_{7} - 5 x_{8} + gamma + pi_{1} \geq 0.0\\
#  & -10 x_{1} - x_{2} - 7 x_{3} - 5 x_{6} - 6 x_{7} - 5 x_{8} + gamma + pi_{2} \geq 0.0\\
#  & -3 x_{1} - 9 x_{2} - 9 x_{3} - 5 x_{4} - 7 x_{6} - 3 x_{7} - 10 x_{8} + gamma + pi_{3} \geq 0.0\\
#  & -10 x_{1} - 4 x_{3} - 10 x_{5} - 7 x_{6} - 6 x_{7} - 2 x_{8} + gamma + pi_{4} \geq 0.0\\
#  & -9 x_{1} - 7 x_{2} - 8 x_{3} - x_{5} - 6 x_{6} - 5 x_{7} + gamma + pi_{5} \geq 0.0\\
#  & -3 x_{1} - 3 x_{2} - 5 x_{3} - 10 x_{4} - 9 x_{5} - x_{6} - 4 x_{7} - 8 x_{8} + gamma + pi_{6} \geq 0.0\\
#  & pi_{1} \geq 0.0\\
#  & pi_{2} \geq 0.0\\
#  & pi_{3} \geq 0.0\\
#  & pi_{4} \geq 0.0\\
#  & pi_{5} \geq 0.0\\
#  & pi_{6} \geq 0.0\\
#  & x_{1} \in \{0, 1\}\\
#  & x_{2} \in \{0, 1\}\\
#  & x_{3} \in \{0, 1\}\\
#  & x_{4} \in \{0, 1\}\\
#  & x_{5} \in \{0, 1\}\\
#  & x_{6} \in \{0, 1\}\\
#  & x_{7} \in \{0, 1\}\\
#  & x_{8} \in \{0, 1\}\\
# \end{aligned} $$
# Solution optimale :
#  x[1] = 0.0
#  x[2] = 0.0
#  x[3] = 0.0
#  x[4] = 1.0
#  x[5] = 0.0
#  x[6] = 1.0
#  x[7] = 1.0
#  x[8] = 0.0
# -44.0

# %% [markdown]
# ## Question 3
# On remarque que le min_max est supérieur au max_min. Montrez que ceci est vrai tout le temps (pour toute matrice $W$). Ainsi dans ce type de jeux, $\underline{\mbox{on n'a pas intérêt à jouer en premier}}$ ...

# %% [markdown]
# ## Question  4
# Supposons qu'une force maléfique suprème peut simulatanément fixer $x$ et $y$ de telle manière que $\sum_{i = 1}^{N_m}  \sum_{j = 1}^{N_a}   x_i y_j w_{i j}$ soit maximal. Il s'agit en quelque sorte de résoudre un problème du type max_max.  Montrez que l'on peut déterminer $x$ et $y$ grâce à la fonction ci-dessous :

# %%
function max_max_int(w, n1 ,k1 , n2, k2)

model=Model(GLPK.Optimizer)

@variable(model, y[1:n2],Bin)
@variable(model, x[1:n1], Bin)
@variable(model, z[1:n1,1:n2], Bin)

@constraint(model,somme_j[j in 1:n2], sum(z[i,j] for i in 1:n1) ==k1*y[j])
@constraint(model,somme_i[i in 1:n1], sum(z[i,j] for j in 1:n2) ==k2*x[i])
@constraint(model,somme_x, sum(x[i] for i in 1:n1) ==k1)
@constraint(model,somme_y, sum(y[j] for j in 1:n2) ==k2)

@objective(model, Max, sum(w[i,j]*z[i,j] for i in 1:n1,j in 1:n2))

print(model)

optimize!(model)

return objective_value(model)

end
# Out:
# max_max_int (generic function with 1 method)

# %%
max_max_int(W,Nm ,km , Na , ka)
# Out:
# $$ \begin{aligned}
# \max\quad & -4 z_{1,1} - 9 z_{1,3} - z_{1,4} - 2 z_{1,5} - 9 z_{1,6} - 4 z_{1,7} - 5 z_{1,8} - 10 z_{2,1} - z_{2,2} - 7 z_{2,3} - 5 z_{2,6} - 6 z_{2,7} - 5 z_{2,8} - 3 z_{3,1} - 9 z_{3,2} - 9 z_{3,3} - 5 z_{3,4} - 7 z_{3,6} - 3 z_{3,7} - 10 z_{3,8} - 10 z_{4,1} - 4 z_{4,3} - 10 z_{4,5} - 7 z_{4,6} - 6 z_{4,7} - 2 z_{4,8} - 9 z_{5,1} - 7 z_{5,2} - 8 z_{5,3} - z_{5,5} - 6 z_{5,6} - 5 z_{5,7} - 3 z_{6,1} - 3 z_{6,2} - 5 z_{6,3} - 10 z_{6,4} - 9 z_{6,5} - z_{6,6} - 4 z_{6,7} - 8 z_{6,8}\\
# \text{Subject to} \quad & -3 y_{1} + z_{1,1} + z_{2,1} + z_{3,1} + z_{4,1} + z_{5,1} + z_{6,1} = 0.0\\
#  & -3 y_{2} + z_{1,2} + z_{2,2} + z_{3,2} + z_{4,2} + z_{5,2} + z_{6,2} = 0.0\\
#  & -3 y_{3} + z_{1,3} + z_{2,3} + z_{3,3} + z_{4,3} + z_{5,3} + z_{6,3} = 0.0\\
#  & -3 y_{4} + z_{1,4} + z_{2,4} + z_{3,4} + z_{4,4} + z_{5,4} + z_{6,4} = 0.0\\
#  & -3 y_{5} + z_{1,5} + z_{2,5} + z_{3,5} + z_{4,5} + z_{5,5} + z_{6,5} = 0.0\\
#  & -3 y_{6} + z_{1,6} + z_{2,6} + z_{3,6} + z_{4,6} + z_{5,6} + z_{6,6} = 0.0\\
#  & -3 y_{7} + z_{1,7} + z_{2,7} + z_{3,7} + z_{4,7} + z_{5,7} + z_{6,7} = 0.0\\
#  & -3 y_{8} + z_{1,8} + z_{2,8} + z_{3,8} + z_{4,8} + z_{5,8} + z_{6,8} = 0.0\\
#  & -3 x_{1} + z_{1,1} + z_{1,2} + z_{1,3} + z_{1,4} + z_{1,5} + z_{1,6} + z_{1,7} + z_{1,8} = 0.0\\
#  & -3 x_{2} + z_{2,1} + z_{2,2} + z_{2,3} + z_{2,4} + z_{2,5} + z_{2,6} + z_{2,7} + z_{2,8} = 0.0\\
#  & -3 x_{3} + z_{3,1} + z_{3,2} + z_{3,3} + z_{3,4} + z_{3,5} + z_{3,6} + z_{3,7} + z_{3,8} = 0.0\\
#  & -3 x_{4} + z_{4,1} + z_{4,2} + z_{4,3} + z_{4,4} + z_{4,5} + z_{4,6} + z_{4,7} + z_{4,8} = 0.0\\
#  & -3 x_{5} + z_{5,1} + z_{5,2} + z_{5,3} + z_{5,4} + z_{5,5} + z_{5,6} + z_{5,7} + z_{5,8} = 0.0\\
#  & -3 x_{6} + z_{6,1} + z_{6,2} + z_{6,3} + z_{6,4} + z_{6,5} + z_{6,6} + z_{6,7} + z_{6,8} = 0.0\\
#  & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} = 3.0\\
#  & y_{1} + y_{2} + y_{3} + y_{4} + y_{5} + y_{6} + y_{7} + y_{8} = 3.0\\
#  & y_{1} \in \{0, 1\}\\
#  & y_{2} \in \{0, 1\}\\
#  & y_{3} \in \{0, 1\}\\
#  & y_{4} \in \{0, 1\}\\
#  & y_{5} \in \{0, 1\}\\
#  & y_{6} \in \{0, 1\}\\
#  & y_{7} \in \{0, 1\}\\
#  & y_{8} \in \{0, 1\}\\
#  & x_{1} \in \{0, 1\}\\
#  & x_{2} \in \{0, 1\}\\
#  & x_{3} \in \{0, 1\}\\
#  & x_{4} \in \{0, 1\}\\
#  & x_{5} \in \{0, 1\}\\
#  & x_{6} \in \{0, 1\}\\
#  & z_{1,1} \in \{0, 1\}\\
#  & z_{2,1} \in \{0, 1\}\\
#  & z_{3,1} \in \{0, 1\}\\
#  & z_{4,1} \in \{0, 1\}\\
#  & z_{5,1} \in \{0, 1\}\\
#  & z_{6,1} \in \{0, 1\}\\
#  & z_{1,2} \in \{0, 1\}\\
#  & z_{2,2} \in \{0, 1\}\\
#  & z_{3,2} \in \{0, 1\}\\
#  & z_{4,2} \in \{0, 1\}\\
#  & z_{5,2} \in \{0, 1\}\\
#  & z_{6,2} \in \{0, 1\}\\
#  & z_{1,3} \in \{0, 1\}\\
#  & z_{2,3} \in \{0, 1\}\\
#  & z_{3,3} \in \{0, 1\}\\
#  & z_{4,3} \in \{0, 1\}\\
#  & z_{5,3} \in \{0, 1\}\\
#  & z_{6,3} \in \{0, 1\}\\
#  & z_{1,4} \in \{0, 1\}\\
#  & z_{2,4} \in \{0, 1\}\\
#  & z_{3,4} \in \{0, 1\}\\
#  & z_{4,4} \in \{0, 1\}\\
#  & z_{5,4} \in \{0, 1\}\\
#  & z_{6,4} \in \{0, 1\}\\
#  & z_{1,5} \in \{0, 1\}\\
#  & z_{2,5} \in \{0, 1\}\\
#  & z_{3,5} \in \{0, 1\}\\
#  & z_{4,5} \in \{0, 1\}\\
#  & z_{5,5} \in \{0, 1\}\\
#  & z_{6,5} \in \{0, 1\}\\
#  & z_{1,6} \in \{0, 1\}\\
#  & z_{2,6} \in \{0, 1\}\\
#  & z_{3,6} \in \{0, 1\}\\
#  & z_{4,6} \in \{0, 1\}\\
#  & z_{5,6} \in \{0, 1\}\\
#  & z_{6,6} \in \{0, 1\}\\
#  & z_{1,7} \in \{0, 1\}\\
#  & z_{2,7} \in \{0, 1\}\\
#  & z_{3,7} \in \{0, 1\}\\
#  & z_{4,7} \in \{0, 1\}\\
#  & z_{5,7} \in \{0, 1\}\\
#  & z_{6,7} \in \{0, 1\}\\
#  & z_{1,8} \in \{0, 1\}\\
#  & z_{2,8} \in \{0, 1\}\\
#  & z_{3,8} \in \{0, 1\}\\
#  & z_{4,8} \in \{0, 1\}\\
#  & z_{5,8} \in \{0, 1\}\\
#  & z_{6,8} \in \{0, 1\}\\
# \end{aligned} $$
# -12.0

# %% [markdown]
# ## Question 5
#
# Supposons mainteant qu'une force bénefique suprème peut simulatanément fixer $x$ et $y$ de telle manière que $\sum_{i = 1}^{N_m}  \sum_{j = 1}^{N_a}   x_i y_j w_{i j}$ soit minimal. Il s'agit donc ici de calculer un min_min.
# Montrez que l'objectif optimal peut être obtenu comme suit :

# %%
(-1)*max_max_int(-W',Na,ka,Nm,km)
# Out:
# $$ \begin{aligned}
# \max\quad & 4 z_{1,1} + 10 z_{1,2} + 3 z_{1,3} + 10 z_{1,4} + 9 z_{1,5} + 3 z_{1,6} + z_{2,2} + 9 z_{2,3} + 7 z_{2,5} + 3 z_{2,6} + 9 z_{3,1} + 7 z_{3,2} + 9 z_{3,3} + 4 z_{3,4} + 8 z_{3,5} + 5 z_{3,6} + z_{4,1} + 5 z_{4,3} + 10 z_{4,6} + 2 z_{5,1} + 10 z_{5,4} + z_{5,5} + 9 z_{5,6} + 9 z_{6,1} + 5 z_{6,2} + 7 z_{6,3} + 7 z_{6,4} + 6 z_{6,5} + z_{6,6} + 4 z_{7,1} + 6 z_{7,2} + 3 z_{7,3} + 6 z_{7,4} + 5 z_{7,5} + 4 z_{7,6} + 5 z_{8,1} + 5 z_{8,2} + 10 z_{8,3} + 2 z_{8,4} + 8 z_{8,6}\\
# \text{Subject to} \quad & -3 y_{1} + z_{1,1} + z_{2,1} + z_{3,1} + z_{4,1} + z_{5,1} + z_{6,1} + z_{7,1} + z_{8,1} = 0.0\\
#  & -3 y_{2} + z_{1,2} + z_{2,2} + z_{3,2} + z_{4,2} + z_{5,2} + z_{6,2} + z_{7,2} + z_{8,2} = 0.0\\
#  & -3 y_{3} + z_{1,3} + z_{2,3} + z_{3,3} + z_{4,3} + z_{5,3} + z_{6,3} + z_{7,3} + z_{8,3} = 0.0\\
#  & -3 y_{4} + z_{1,4} + z_{2,4} + z_{3,4} + z_{4,4} + z_{5,4} + z_{6,4} + z_{7,4} + z_{8,4} = 0.0\\
#  & -3 y_{5} + z_{1,5} + z_{2,5} + z_{3,5} + z_{4,5} + z_{5,5} + z_{6,5} + z_{7,5} + z_{8,5} = 0.0\\
#  & -3 y_{6} + z_{1,6} + z_{2,6} + z_{3,6} + z_{4,6} + z_{5,6} + z_{6,6} + z_{7,6} + z_{8,6} = 0.0\\
#  & -3 x_{1} + z_{1,1} + z_{1,2} + z_{1,3} + z_{1,4} + z_{1,5} + z_{1,6} = 0.0\\
#  & -3 x_{2} + z_{2,1} + z_{2,2} + z_{2,3} + z_{2,4} + z_{2,5} + z_{2,6} = 0.0\\
#  & -3 x_{3} + z_{3,1} + z_{3,2} + z_{3,3} + z_{3,4} + z_{3,5} + z_{3,6} = 0.0\\
#  & -3 x_{4} + z_{4,1} + z_{4,2} + z_{4,3} + z_{4,4} + z_{4,5} + z_{4,6} = 0.0\\
#  & -3 x_{5} + z_{5,1} + z_{5,2} + z_{5,3} + z_{5,4} + z_{5,5} + z_{5,6} = 0.0\\
#  & -3 x_{6} + z_{6,1} + z_{6,2} + z_{6,3} + z_{6,4} + z_{6,5} + z_{6,6} = 0.0\\
#  & -3 x_{7} + z_{7,1} + z_{7,2} + z_{7,3} + z_{7,4} + z_{7,5} + z_{7,6} = 0.0\\
#  & -3 x_{8} + z_{8,1} + z_{8,2} + z_{8,3} + z_{8,4} + z_{8,5} + z_{8,6} = 0.0\\
#  & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} + x_{7} + x_{8} = 3.0\\
#  & y_{1} + y_{2} + y_{3} + y_{4} + y_{5} + y_{6} = 3.0\\
#  & y_{1} \in \{0, 1\}\\
#  & y_{2} \in \{0, 1\}\\
#  & y_{3} \in \{0, 1\}\\
#  & y_{4} \in \{0, 1\}\\
#  & y_{5} \in \{0, 1\}\\
#  & y_{6} \in \{0, 1\}\\
#  & x_{1} \in \{0, 1\}\\
#  & x_{2} \in \{0, 1\}\\
#  & x_{3} \in \{0, 1\}\\
#  & x_{4} \in \{0, 1\}\\
#  & x_{5} \in \{0, 1\}\\
#  & x_{6} \in \{0, 1\}\\
#  & x_{7} \in \{0, 1\}\\
#  & x_{8} \in \{0, 1\}\\
#  & z_{1,1} \in \{0, 1\}\\
#  & z_{2,1} \in \{0, 1\}\\
#  & z_{3,1} \in \{0, 1\}\\
#  & z_{4,1} \in \{0, 1\}\\
#  & z_{5,1} \in \{0, 1\}\\
#  & z_{6,1} \in \{0, 1\}\\
#  & z_{7,1} \in \{0, 1\}\\
#  & z_{8,1} \in \{0, 1\}\\
#  & z_{1,2} \in \{0, 1\}\\
#  & z_{2,2} \in \{0, 1\}\\
#  & z_{3,2} \in \{0, 1\}\\
#  & z_{4,2} \in \{0, 1\}\\
#  & z_{5,2} \in \{0, 1\}\\
#  & z_{6,2} \in \{0, 1\}\\
#  & z_{7,2} \in \{0, 1\}\\
#  & z_{8,2} \in \{0, 1\}\\
#  & z_{1,3} \in \{0, 1\}\\
#  & z_{2,3} \in \{0, 1\}\\
#  & z_{3,3} \in \{0, 1\}\\
#  & z_{4,3} \in \{0, 1\}\\
#  & z_{5,3} \in \{0, 1\}\\
#  & z_{6,3} \in \{0, 1\}\\
#  & z_{7,3} \in \{0, 1\}\\
#  & z_{8,3} \in \{0, 1\}\\
#  & z_{1,4} \in \{0, 1\}\\
#  & z_{2,4} \in \{0, 1\}\\
#  & z_{3,4} \in \{0, 1\}\\
#  & z_{4,4} \in \{0, 1\}\\
#  & z_{5,4} \in \{0, 1\}\\
#  & z_{6,4} \in \{0, 1\}\\
#  & z_{7,4} \in \{0, 1\}\\
#  & z_{8,4} \in \{0, 1\}\\
#  & z_{1,5} \in \{0, 1\}\\
#  & z_{2,5} \in \{0, 1\}\\
#  & z_{3,5} \in \{0, 1\}\\
#  & z_{4,5} \in \{0, 1\}\\
#  & z_{5,5} \in \{0, 1\}\\
#  & z_{6,5} \in \{0, 1\}\\
#  & z_{7,5} \in \{0, 1\}\\
#  & z_{8,5} \in \{0, 1\}\\
#  & z_{1,6} \in \{0, 1\}\\
#  & z_{2,6} \in \{0, 1\}\\
#  & z_{3,6} \in \{0, 1\}\\
#  & z_{4,6} \in \{0, 1\}\\
#  & z_{5,6} \in \{0, 1\}\\
#  & z_{6,6} \in \{0, 1\}\\
#  & z_{7,6} \in \{0, 1\}\\
#  & z_{8,6} \in \{0, 1\}\\
# \end{aligned} $$
# -67.0

# %% [markdown]
# ## Question 6
#
# Expliquez pourquoi on a $\max \max \geq \min \max \geq \max \min \geq \min \min$.

# %% [markdown]
# ## Question 7
#
# La stratégie qui consiste à fixer la valeur de chaque $x_i$ à $1$ ou $0$ est dite pure. L'opérateur (ainsi que l'attaquant) peuvent avoir des stratégies probabilistes mixtes où les $x_i$ et les $y_j$ peuvent prendre des valeurs fractionnaires. Ainsi, pour une valeur fractionnaire $x_i$, l'opérateur décide d'adopter la mesure $i$ avec une probabilité $x_i$ et de ne pas l'adpoter avec la probabilité $1 - x_i$. L'attaquant fait de même en ce qui concerne les attaques. ces strtatégies sont dites des stratégies mixtes puisqu'elle combinent des stratégies pures. Si l'opérateur joue en premier, il devra alors résoudre une version continue du problème (2). Ecrivez vous même un code pour la fonction  min_max_frac(w, n1 ,k1 , n2, k2).

# %% [markdown]
# Appliquez votre fonction et vérifiez que vous obtenez un impact optimal de
# -42.18377976190476

# %% [markdown]
# Utilisez la fonction que vous venez de coder pour maximiser l'impact lorsque l'attaquant commence à jouer (vous pouvez par exemple appliquer (-1)*min_max_frac(-W',Na,ka,Nm, km)).
#
# Qu'est ce qu'on remarque ??  Tentez une explication en faisant le rapprochement avec le théroème de Sion, ou en utilisant la dualité....
#
# En fait, on vient d'obtenir ce qu'on appelle un  $\underline{\mbox{équilibre de Nash}}$   (une stratégie mixte optimale  pour chacun des 2 jeux telle que aucun des 2 joueurs n'a intérêt à en dévier....)

# %% [markdown]
# ## Question 8
# Nous allons maintenant étudier des relaxations continues pour le problème max_max (qu'on a résolu à l'aide de la fonction max_max_int). Naturellment, des relaxations seront aussi déduites pour le problème min_min. Commençons par cette première relaxation :

# %%
function max_max_int_relax1(w, n1 ,k1 , n2, k2)

model=Model(GLPK.Optimizer)

@variable(model, 0<=y[1:n2]<=1)
@variable(model, 0<=x[1:n1]<=1)
@variable(model, 0<=z[1:n1,1:n2]<=1)

@constraint(model,somme_j[j in 1:n2], sum(z[i,j] for i in 1:n1) ==k1*y[j])
@constraint(model,somme_i[i in 1:n1], sum(z[i,j] for j in 1:n2) ==k2*x[i])
@constraint(model,somme_x, sum(x[i] for i in 1:n1) ==k1)
@constraint(model,somme_y, sum(y[j] for j in 1:n2) ==k2)

@objective(model, Max, sum(w[i,j]*z[i,j] for i in 1:n1,j in 1:n2))

print(model)

optimize!(model)

return objective_value(model)

end

max_max_int_relax1(W,Nm ,km , Na , ka)
# Out:
# $$ \begin{aligned}
# \max\quad & -4 z_{1,1} - 9 z_{1,3} - z_{1,4} - 2 z_{1,5} - 9 z_{1,6} - 4 z_{1,7} - 5 z_{1,8} - 10 z_{2,1} - z_{2,2} - 7 z_{2,3} - 5 z_{2,6} - 6 z_{2,7} - 5 z_{2,8} - 3 z_{3,1} - 9 z_{3,2} - 9 z_{3,3} - 5 z_{3,4} - 7 z_{3,6} - 3 z_{3,7} - 10 z_{3,8} - 10 z_{4,1} - 4 z_{4,3} - 10 z_{4,5} - 7 z_{4,6} - 6 z_{4,7} - 2 z_{4,8} - 9 z_{5,1} - 7 z_{5,2} - 8 z_{5,3} - z_{5,5} - 6 z_{5,6} - 5 z_{5,7} - 3 z_{6,1} - 3 z_{6,2} - 5 z_{6,3} - 10 z_{6,4} - 9 z_{6,5} - z_{6,6} - 4 z_{6,7} - 8 z_{6,8}\\
# \text{Subject to} \quad & -3 y_{1} + z_{1,1} + z_{2,1} + z_{3,1} + z_{4,1} + z_{5,1} + z_{6,1} = 0.0\\
#  & -3 y_{2} + z_{1,2} + z_{2,2} + z_{3,2} + z_{4,2} + z_{5,2} + z_{6,2} = 0.0\\
#  & -3 y_{3} + z_{1,3} + z_{2,3} + z_{3,3} + z_{4,3} + z_{5,3} + z_{6,3} = 0.0\\
#  & -3 y_{4} + z_{1,4} + z_{2,4} + z_{3,4} + z_{4,4} + z_{5,4} + z_{6,4} = 0.0\\
#  & -3 y_{5} + z_{1,5} + z_{2,5} + z_{3,5} + z_{4,5} + z_{5,5} + z_{6,5} = 0.0\\
#  & -3 y_{6} + z_{1,6} + z_{2,6} + z_{3,6} + z_{4,6} + z_{5,6} + z_{6,6} = 0.0\\
#  & -3 y_{7} + z_{1,7} + z_{2,7} + z_{3,7} + z_{4,7} + z_{5,7} + z_{6,7} = 0.0\\
#  & -3 y_{8} + z_{1,8} + z_{2,8} + z_{3,8} + z_{4,8} + z_{5,8} + z_{6,8} = 0.0\\
#  & -3 x_{1} + z_{1,1} + z_{1,2} + z_{1,3} + z_{1,4} + z_{1,5} + z_{1,6} + z_{1,7} + z_{1,8} = 0.0\\
#  & -3 x_{2} + z_{2,1} + z_{2,2} + z_{2,3} + z_{2,4} + z_{2,5} + z_{2,6} + z_{2,7} + z_{2,8} = 0.0\\
#  & -3 x_{3} + z_{3,1} + z_{3,2} + z_{3,3} + z_{3,4} + z_{3,5} + z_{3,6} + z_{3,7} + z_{3,8} = 0.0\\
#  & -3 x_{4} + z_{4,1} + z_{4,2} + z_{4,3} + z_{4,4} + z_{4,5} + z_{4,6} + z_{4,7} + z_{4,8} = 0.0\\
#  & -3 x_{5} + z_{5,1} + z_{5,2} + z_{5,3} + z_{5,4} + z_{5,5} + z_{5,6} + z_{5,7} + z_{5,8} = 0.0\\
#  & -3 x_{6} + z_{6,1} + z_{6,2} + z_{6,3} + z_{6,4} + z_{6,5} + z_{6,6} + z_{6,7} + z_{6,8} = 0.0\\
#  & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} = 3.0\\
#  & y_{1} + y_{2} + y_{3} + y_{4} + y_{5} + y_{6} + y_{7} + y_{8} = 3.0\\
#  & y_{1} \geq 0.0\\
#  & y_{2} \geq 0.0\\
#  & y_{3} \geq 0.0\\
#  & y_{4} \geq 0.0\\
#  & y_{5} \geq 0.0\\
#  & y_{6} \geq 0.0\\
#  & y_{7} \geq 0.0\\
#  & y_{8} \geq 0.0\\
#  & x_{1} \geq 0.0\\
#  & x_{2} \geq 0.0\\
#  & x_{3} \geq 0.0\\
#  & x_{4} \geq 0.0\\
#  & x_{5} \geq 0.0\\
#  & x_{6} \geq 0.0\\
#  & z_{1,1} \geq 0.0\\
#  & z_{2,1} \geq 0.0\\
#  & z_{3,1} \geq 0.0\\
#  & z_{4,1} \geq 0.0\\
#  & z_{5,1} \geq 0.0\\
#  & z_{6,1} \geq 0.0\\
#  & z_{1,2} \geq 0.0\\
#  & z_{2,2} \geq 0.0\\
#  & z_{3,2} \geq 0.0\\
#  & z_{4,2} \geq 0.0\\
#  & z_{5,2} \geq 0.0\\
#  & z_{6,2} \geq 0.0\\
#  & z_{1,3} \geq 0.0\\
#  & z_{2,3} \geq 0.0\\
#  & z_{3,3} \geq 0.0\\
#  & z_{4,3} \geq 0.0\\
#  & z_{5,3} \geq 0.0\\
#  & z_{6,3} \geq 0.0\\
#  & z_{1,4} \geq 0.0\\
#  & z_{2,4} \geq 0.0\\
#  & z_{3,4} \geq 0.0\\
#  & z_{4,4} \geq 0.0\\
#  & z_{5,4} \geq 0.0\\
#  & z_{6,4} \geq 0.0\\
#  & z_{1,5} \geq 0.0\\
#  & z_{2,5} \geq 0.0\\
#  & z_{3,5} \geq 0.0\\
#  & z_{4,5} \geq 0.0\\
#  & z_{5,5} \geq 0.0\\
#  & z_{6,5} \geq 0.0\\
#  & z_{1,6} \geq 0.0\\
#  & z_{2,6} \geq 0.0\\
#  & z_{3,6} \geq 0.0\\
#  & z_{4,6} \geq 0.0\\
#  & z_{5,6} \geq 0.0\\
#  & z_{6,6} \geq 0.0\\
#  & z_{1,7} \geq 0.0\\
#  & z_{2,7} \geq 0.0\\
#  & z_{3,7} \geq 0.0\\
#  & z_{4,7} \geq 0.0\\
#  & z_{5,7} \geq 0.0\\
#  & z_{6,7} \geq 0.0\\
#  & z_{1,8} \geq 0.0\\
#  & z_{2,8} \geq 0.0\\
#  & z_{3,8} \geq 0.0\\
#  & z_{4,8} \geq 0.0\\
#  & z_{5,8} \geq 0.0\\
#  & z_{6,8} \geq 0.0\\
#  & y_{1} \leq 1.0\\
#  & y_{2} \leq 1.0\\
#  & y_{3} \leq 1.0\\
#  & y_{4} \leq 1.0\\
#  & y_{5} \leq 1.0\\
#  & y_{6} \leq 1.0\\
#  & y_{7} \leq 1.0\\
#  & y_{8} \leq 1.0\\
#  & x_{1} \leq 1.0\\
#  & x_{2} \leq 1.0\\
#  & x_{3} \leq 1.0\\
#  & x_{4} \leq 1.0\\
#  & x_{5} \leq 1.0\\
#  & x_{6} \leq 1.0\\
#  & z_{1,1} \leq 1.0\\
#  & z_{2,1} \leq 1.0\\
#  & z_{3,1} \leq 1.0\\
#  & z_{4,1} \leq 1.0\\
#  & z_{5,1} \leq 1.0\\
#  & z_{6,1} \leq 1.0\\
#  & z_{1,2} \leq 1.0\\
#  & z_{2,2} \leq 1.0\\
#  & z_{3,2} \leq 1.0\\
#  & z_{4,2} \leq 1.0\\
#  & z_{5,2} \leq 1.0\\
#  & z_{6,2} \leq 1.0\\
#  & z_{1,3} \leq 1.0\\
#  & z_{2,3} \leq 1.0\\
#  & z_{3,3} \leq 1.0\\
#  & z_{4,3} \leq 1.0\\
#  & z_{5,3} \leq 1.0\\
#  & z_{6,3} \leq 1.0\\
#  & z_{1,4} \leq 1.0\\
#  & z_{2,4} \leq 1.0\\
#  & z_{3,4} \leq 1.0\\
#  & z_{4,4} \leq 1.0\\
#  & z_{5,4} \leq 1.0\\
#  & z_{6,4} \leq 1.0\\
#  & z_{1,5} \leq 1.0\\
#  & z_{2,5} \leq 1.0\\
#  & z_{3,5} \leq 1.0\\
#  & z_{4,5} \leq 1.0\\
#  & z_{5,5} \leq 1.0\\
#  & z_{6,5} \leq 1.0\\
#  & z_{1,6} \leq 1.0\\
#  & z_{2,6} \leq 1.0\\
#  & z_{3,6} \leq 1.0\\
#  & z_{4,6} \leq 1.0\\
#  & z_{5,6} \leq 1.0\\
#  & z_{6,6} \leq 1.0\\
#  & z_{1,7} \leq 1.0\\
#  & z_{2,7} \leq 1.0\\
#  & z_{3,7} \leq 1.0\\
#  & z_{4,7} \leq 1.0\\
#  & z_{5,7} \leq 1.0\\
#  & z_{6,7} \leq 1.0\\
#  & z_{1,8} \leq 1.0\\
#  & z_{2,8} \leq 1.0\\
#  & z_{3,8} \leq 1.0\\
#  & z_{4,8} \leq 1.0\\
#  & z_{5,8} \leq 1.0\\
#  & z_{6,8} \leq 1.0\\
# \end{aligned} $$
# -1.0000000000000013

# %% [markdown]
# Montrez la validité de cette relaxation.

# %% [markdown]
# ## Question 9
# Allons un peu plus loin en rajoutant quelques inégalités valides.

# %%
function max_max_int_relax2(w, n1 ,k1 , n2, k2)

model=Model(GLPK.Optimizer)

@variable(model, 0<=y[1:n2]<=1)
@variable(model, 0<=x[1:n1]<=1)
@variable(model, 0<=z[1:n1,1:n2]<=1)

@constraint(model,somme_j[j in 1:n2], sum(z[i,j] for i in 1:n1) ==k1*y[j])
@constraint(model,somme_i[i in 1:n1], sum(z[i,j] for j in 1:n2) ==k2*x[i])
@constraint(model,somme_x, sum(x[i] for i in 1:n1) ==k1)
@constraint(model,somme_y, sum(y[j] for j in 1:n2) ==k2)

@objective(model, Max, sum(w[i,j]*z[i,j] for i in 1:n1,j in 1:n2))

@constraint(model, RLT1[i in 1:n1,j in 1:n2],z[i,j]-x[i]<=0)
@constraint(model, RLT2[i in 1:n1,j in 1:n2],z[i,j]-y[j]<=0)

print(model)
optimize!(model)

return objective_value(model)

end

max_max_int_relax2(W,Nm ,km , Na , ka)
# Out:
# $$ \begin{aligned}
# \max\quad & -4 z_{1,1} - 9 z_{1,3} - z_{1,4} - 2 z_{1,5} - 9 z_{1,6} - 4 z_{1,7} - 5 z_{1,8} - 10 z_{2,1} - z_{2,2} - 7 z_{2,3} - 5 z_{2,6} - 6 z_{2,7} - 5 z_{2,8} - 3 z_{3,1} - 9 z_{3,2} - 9 z_{3,3} - 5 z_{3,4} - 7 z_{3,6} - 3 z_{3,7} - 10 z_{3,8} - 10 z_{4,1} - 4 z_{4,3} - 10 z_{4,5} - 7 z_{4,6} - 6 z_{4,7} - 2 z_{4,8} - 9 z_{5,1} - 7 z_{5,2} - 8 z_{5,3} - z_{5,5} - 6 z_{5,6} - 5 z_{5,7} - 3 z_{6,1} - 3 z_{6,2} - 5 z_{6,3} - 10 z_{6,4} - 9 z_{6,5} - z_{6,6} - 4 z_{6,7} - 8 z_{6,8}\\
# \text{Subject to} \quad & -3 y_{1} + z_{1,1} + z_{2,1} + z_{3,1} + z_{4,1} + z_{5,1} + z_{6,1} = 0.0\\
#  & -3 y_{2} + z_{1,2} + z_{2,2} + z_{3,2} + z_{4,2} + z_{5,2} + z_{6,2} = 0.0\\
#  & -3 y_{3} + z_{1,3} + z_{2,3} + z_{3,3} + z_{4,3} + z_{5,3} + z_{6,3} = 0.0\\
#  & -3 y_{4} + z_{1,4} + z_{2,4} + z_{3,4} + z_{4,4} + z_{5,4} + z_{6,4} = 0.0\\
#  & -3 y_{5} + z_{1,5} + z_{2,5} + z_{3,5} + z_{4,5} + z_{5,5} + z_{6,5} = 0.0\\
#  & -3 y_{6} + z_{1,6} + z_{2,6} + z_{3,6} + z_{4,6} + z_{5,6} + z_{6,6} = 0.0\\
#  & -3 y_{7} + z_{1,7} + z_{2,7} + z_{3,7} + z_{4,7} + z_{5,7} + z_{6,7} = 0.0\\
#  & -3 y_{8} + z_{1,8} + z_{2,8} + z_{3,8} + z_{4,8} + z_{5,8} + z_{6,8} = 0.0\\
#  & -3 x_{1} + z_{1,1} + z_{1,2} + z_{1,3} + z_{1,4} + z_{1,5} + z_{1,6} + z_{1,7} + z_{1,8} = 0.0\\
#  & -3 x_{2} + z_{2,1} + z_{2,2} + z_{2,3} + z_{2,4} + z_{2,5} + z_{2,6} + z_{2,7} + z_{2,8} = 0.0\\
#  & -3 x_{3} + z_{3,1} + z_{3,2} + z_{3,3} + z_{3,4} + z_{3,5} + z_{3,6} + z_{3,7} + z_{3,8} = 0.0\\
#  & -3 x_{4} + z_{4,1} + z_{4,2} + z_{4,3} + z_{4,4} + z_{4,5} + z_{4,6} + z_{4,7} + z_{4,8} = 0.0\\
#  & -3 x_{5} + z_{5,1} + z_{5,2} + z_{5,3} + z_{5,4} + z_{5,5} + z_{5,6} + z_{5,7} + z_{5,8} = 0.0\\
#  & -3 x_{6} + z_{6,1} + z_{6,2} + z_{6,3} + z_{6,4} + z_{6,5} + z_{6,6} + z_{6,7} + z_{6,8} = 0.0\\
#  & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} = 3.0\\
#  & y_{1} + y_{2} + y_{3} + y_{4} + y_{5} + y_{6} + y_{7} + y_{8} = 3.0\\
#  & -x_{1} + z_{1,1} \leq 0.0\\
#  & -x_{2} + z_{2,1} \leq 0.0\\
#  & -x_{3} + z_{3,1} \leq 0.0\\
#  & -x_{4} + z_{4,1} \leq 0.0\\
#  & -x_{5} + z_{5,1} \leq 0.0\\
#  & -x_{6} + z_{6,1} \leq 0.0\\
#  & -x_{1} + z_{1,2} \leq 0.0\\
#  & -x_{2} + z_{2,2} \leq 0.0\\
#  & -x_{3} + z_{3,2} \leq 0.0\\
#  & -x_{4} + z_{4,2} \leq 0.0\\
#  & -x_{5} + z_{5,2} \leq 0.0\\
#  & -x_{6} + z_{6,2} \leq 0.0\\
#  & -x_{1} + z_{1,3} \leq 0.0\\
#  & -x_{2} + z_{2,3} \leq 0.0\\
#  & -x_{3} + z_{3,3} \leq 0.0\\
#  & -x_{4} + z_{4,3} \leq 0.0\\
#  & -x_{5} + z_{5,3} \leq 0.0\\
#  & -x_{6} + z_{6,3} \leq 0.0\\
#  & -x_{1} + z_{1,4} \leq 0.0\\
#  & -x_{2} + z_{2,4} \leq 0.0\\
#  & -x_{3} + z_{3,4} \leq 0.0\\
#  & -x_{4} + z_{4,4} \leq 0.0\\
#  & -x_{5} + z_{5,4} \leq 0.0\\
#  & -x_{6} + z_{6,4} \leq 0.0\\
#  & -x_{1} + z_{1,5} \leq 0.0\\
#  & -x_{2} + z_{2,5} \leq 0.0\\
#  & -x_{3} + z_{3,5} \leq 0.0\\
#  & -x_{4} + z_{4,5} \leq 0.0\\
#  & -x_{5} + z_{5,5} \leq 0.0\\
#  & -x_{6} + z_{6,5} \leq 0.0\\
#  & -x_{1} + z_{1,6} \leq 0.0\\
#  & -x_{2} + z_{2,6} \leq 0.0\\
#  & -x_{3} + z_{3,6} \leq 0.0\\
#  & -x_{4} + z_{4,6} \leq 0.0\\
#  & -x_{5} + z_{5,6} \leq 0.0\\
#  & -x_{6} + z_{6,6} \leq 0.0\\
#  & -x_{1} + z_{1,7} \leq 0.0\\
#  & -x_{2} + z_{2,7} \leq 0.0\\
#  & -x_{3} + z_{3,7} \leq 0.0\\
#  & -x_{4} + z_{4,7} \leq 0.0\\
#  & -x_{5} + z_{5,7} \leq 0.0\\
#  & -x_{6} + z_{6,7} \leq 0.0\\
#  & -x_{1} + z_{1,8} \leq 0.0\\
#  & -x_{2} + z_{2,8} \leq 0.0\\
#  & -x_{3} + z_{3,8} \leq 0.0\\
#  & -x_{4} + z_{4,8} \leq 0.0\\
#  & -x_{5} + z_{5,8} \leq 0.0\\
#  & -x_{6} + z_{6,8} \leq 0.0\\
#  & -y_{1} + z_{1,1} \leq 0.0\\
#  & -y_{1} + z_{2,1} \leq 0.0\\
#  & -y_{1} + z_{3,1} \leq 0.0\\
#  & -y_{1} + z_{4,1} \leq 0.0\\
#  & -y_{1} + z_{5,1} \leq 0.0\\
#  & -y_{1} + z_{6,1} \leq 0.0\\
#  & -y_{2} + z_{1,2} \leq 0.0\\
#  & -y_{2} + z_{2,2} \leq 0.0\\
#  & -y_{2} + z_{3,2} \leq 0.0\\
#  & -y_{2} + z_{4,2} \leq 0.0\\
#  & -y_{2} + z_{5,2} \leq 0.0\\
#  & -y_{2} + z_{6,2} \leq 0.0\\
#  & -y_{3} + z_{1,3} \leq 0.0\\
#  & -y_{3} + z_{2,3} \leq 0.0\\
#  & -y_{3} + z_{3,3} \leq 0.0\\
#  & -y_{3} + z_{4,3} \leq 0.0\\
#  & -y_{3} + z_{5,3} \leq 0.0\\
#  & -y_{3} + z_{6,3} \leq 0.0\\
#  & -y_{4} + z_{1,4} \leq 0.0\\
#  & -y_{4} + z_{2,4} \leq 0.0\\
#  & -y_{4} + z_{3,4} \leq 0.0\\
#  & -y_{4} + z_{4,4} \leq 0.0\\
#  & -y_{4} + z_{5,4} \leq 0.0\\
#  & -y_{4} + z_{6,4} \leq 0.0\\
#  & -y_{5} + z_{1,5} \leq 0.0\\
#  & -y_{5} + z_{2,5} \leq 0.0\\
#  & -y_{5} + z_{3,5} \leq 0.0\\
#  & -y_{5} + z_{4,5} \leq 0.0\\
#  & -y_{5} + z_{5,5} \leq 0.0\\
#  & -y_{5} + z_{6,5} \leq 0.0\\
#  & -y_{6} + z_{1,6} \leq 0.0\\
#  & -y_{6} + z_{2,6} \leq 0.0\\
#  & -y_{6} + z_{3,6} \leq 0.0\\
#  & -y_{6} + z_{4,6} \leq 0.0\\
#  & -y_{6} + z_{5,6} \leq 0.0\\
#  & -y_{6} + z_{6,6} \leq 0.0\\
#  & -y_{7} + z_{1,7} \leq 0.0\\
#  & -y_{7} + z_{2,7} \leq 0.0\\
#  & -y_{7} + z_{3,7} \leq 0.0\\
#  & -y_{7} + z_{4,7} \leq 0.0\\
#  & -y_{7} + z_{5,7} \leq 0.0\\
#  & -y_{7} + z_{6,7} \leq 0.0\\
#  & -y_{8} + z_{1,8} \leq 0.0\\
#  & -y_{8} + z_{2,8} \leq 0.0\\
#  & -y_{8} + z_{3,8} \leq 0.0\\
#  & -y_{8} + z_{4,8} \leq 0.0\\
#  & -y_{8} + z_{5,8} \leq 0.0\\
#  & -y_{8} + z_{6,8} \leq 0.0\\
#  & y_{1} \geq 0.0\\
#  & y_{2} \geq 0.0\\
#  & y_{3} \geq 0.0\\
#  & y_{4} \geq 0.0\\
#  & y_{5} \geq 0.0\\
#  & y_{6} \geq 0.0\\
#  & y_{7} \geq 0.0\\
#  & y_{8} \geq 0.0\\
#  & x_{1} \geq 0.0\\
#  & x_{2} \geq 0.0\\
#  & x_{3} \geq 0.0\\
#  & x_{4} \geq 0.0\\
#  & x_{5} \geq 0.0\\
#  & x_{6} \geq 0.0\\
#  & z_{1,1} \geq 0.0\\
#  & z_{2,1} \geq 0.0\\
#  & z_{3,1} \geq 0.0\\
#  & z_{4,1} \geq 0.0\\
#  & z_{5,1} \geq 0.0\\
#  & z_{6,1} \geq 0.0\\
#  & z_{1,2} \geq 0.0\\
#  & z_{2,2} \geq 0.0\\
#  & z_{3,2} \geq 0.0\\
#  & z_{4,2} \geq 0.0\\
#  & z_{5,2} \geq 0.0\\
#  & z_{6,2} \geq 0.0\\
#  & z_{1,3} \geq 0.0\\
#  & z_{2,3} \geq 0.0\\
#  & z_{3,3} \geq 0.0\\
#  & z_{4,3} \geq 0.0\\
#  & z_{5,3} \geq 0.0\\
#  & z_{6,3} \geq 0.0\\
#  & z_{1,4} \geq 0.0\\
#  & z_{2,4} \geq 0.0\\
#  & z_{3,4} \geq 0.0\\
#  & z_{4,4} \geq 0.0\\
#  & z_{5,4} \geq 0.0\\
#  & z_{6,4} \geq 0.0\\
#  & z_{1,5} \geq 0.0\\
#  & z_{2,5} \geq 0.0\\
#  & z_{3,5} \geq 0.0\\
#  & z_{4,5} \geq 0.0\\
#  & z_{5,5} \geq 0.0\\
#  & z_{6,5} \geq 0.0\\
#  & z_{1,6} \geq 0.0\\
#  & z_{2,6} \geq 0.0\\
#  & z_{3,6} \geq 0.0\\
#  & z_{4,6} \geq 0.0\\
#  & z_{5,6} \geq 0.0\\
#  & z_{6,6} \geq 0.0\\
#  & z_{1,7} \geq 0.0\\
#  & z_{2,7} \geq 0.0\\
#  & z_{3,7} \geq 0.0\\
#  & z_{4,7} \geq 0.0\\
#  & z_{5,7} \geq 0.0\\
#  & z_{6,7} \geq 0.0\\
#  & z_{1,8} \geq 0.0\\
#  & z_{2,8} \geq 0.0\\
#  & z_{3,8} \geq 0.0\\
#  & z_{4,8} \geq 0.0\\
#  & z_{5,8} \geq 0.0\\
#  & z_{6,8} \geq 0.0\\
#  & y_{1} \leq 1.0\\
#  & y_{2} \leq 1.0\\
#  & y_{3} \leq 1.0\\
#  & y_{4} \leq 1.0\\
#  & y_{5} \leq 1.0\\
#  & y_{6} \leq 1.0\\
#  & y_{7} \leq 1.0\\
#  & y_{8} \leq 1.0\\
#  & x_{1} \leq 1.0\\
#  & x_{2} \leq 1.0\\
#  & x_{3} \leq 1.0\\
#  & x_{4} \leq 1.0\\
#  & x_{5} \leq 1.0\\
#  & x_{6} \leq 1.0\\
#  & z_{1,1} \leq 1.0\\
#  & z_{2,1} \leq 1.0\\
#  & z_{3,1} \leq 1.0\\
#  & z_{4,1} \leq 1.0\\
#  & z_{5,1} \leq 1.0\\
#  & z_{6,1} \leq 1.0\\
#  & z_{1,2} \leq 1.0\\
#  & z_{2,2} \leq 1.0\\
#  & z_{3,2} \leq 1.0\\
#  & z_{4,2} \leq 1.0\\
#  & z_{5,2} \leq 1.0\\
#  & z_{6,2} \leq 1.0\\
#  & z_{1,3} \leq 1.0\\
#  & z_{2,3} \leq 1.0\\
#  & z_{3,3} \leq 1.0\\
#  & z_{4,3} \leq 1.0\\
#  & z_{5,3} \leq 1.0\\
#  & z_{6,3} \leq 1.0\\
#  & z_{1,4} \leq 1.0\\
#  & z_{2,4} \leq 1.0\\
#  & z_{3,4} \leq 1.0\\
#  & z_{4,4} \leq 1.0\\
#  & z_{5,4} \leq 1.0\\
#  & z_{6,4} \leq 1.0\\
#  & z_{1,5} \leq 1.0\\
#  & z_{2,5} \leq 1.0\\
#  & z_{3,5} \leq 1.0\\
#  & z_{4,5} \leq 1.0\\
#  & z_{5,5} \leq 1.0\\
#  & z_{6,5} \leq 1.0\\
#  & z_{1,6} \leq 1.0\\
#  & z_{2,6} \leq 1.0\\
#  & z_{3,6} \leq 1.0\\
#  & z_{4,6} \leq 1.0\\
#  & z_{5,6} \leq 1.0\\
#  & z_{6,6} \leq 1.0\\
#  & z_{1,7} \leq 1.0\\
#  & z_{2,7} \leq 1.0\\
#  & z_{3,7} \leq 1.0\\
#  & z_{4,7} \leq 1.0\\
#  & z_{5,7} \leq 1.0\\
#  & z_{6,7} \leq 1.0\\
#  & z_{1,8} \leq 1.0\\
#  & z_{2,8} \leq 1.0\\
#  & z_{3,8} \leq 1.0\\
#  & z_{4,8} \leq 1.0\\
#  & z_{5,8} \leq 1.0\\
#  & z_{6,8} \leq 1.0\\
# \end{aligned} $$
# -8.000000000000023

# %% [markdown]
# Montrez la validité de cette relaxation et observez l'apport de ce renforcement par rapport à la relaxation précédente.

# %% [markdown]
# ## Question 10
# Nous allons renforcer la relaxation à l'aide de contraintes SDP. Nous considérons la matrice $U$ symétrique de taille $N_a + N_m + 1$  qui représente le produit $\left(\begin{array}{r} & x \\ & y \\ & 1  \end{array}\right) \times \left(\begin{array}{l}  & x \\ & y \\ & 1 \\  \end{array} \right)^T$. En utilisant le lemme du complément de Schur, montrez qu'écrire que  $U$ est SDP est équivalent à exiger que la matrice principale de taille $N_a + N_m$ (en haut à gauche) définie pat   $U[1:N_a+N_m,1:N_a+N_m]$ vérifie $U[1:N_a+N_m,1:N_a+N_m] -   \left(\begin{array}{l}  & x \\ & y  \\  \end{array} \right) \left(\begin{array}{l}  & x \\ & y  \\  \end{array} \right)^T$ est SDP. Ainsi la contrainte $U =  \left(\begin{array}{r} & x \\ & y \\ & 1  \end{array}\right) \times \left(\begin{array}{l}  & x \\ & y \\ & 1 \\  \end{array} \right)^T$ est relachée en la contrainte convexe $U[1:N_a+N_m,1:N_a+N_m] -   \left(\begin{array}{l}  & x \\ & y  \\  \end{array} \right) \left(\begin{array}{l}  & x \\ & y  \\  \end{array} \right)^T$ est SDP,  qui est donc équivalente à $U$ est SDP sachant que la dernière colonne de $U$ est égale au vecteur $\left(\begin{array}{r} & x \\ & y \\ & 1  \end{array}\right)$.
# Nous allons donc implémenter et résoudre une relaxation intégrant cette contrainte SDP. Nous avons besoin d'un solveur qui traite ce type de contrainte. Nous pouvons par exemple utiliser le solveur SCS.

# %%
Pkg.add("SCS")
using SCS
# Out:
#    Resolving package versions...
#    Installed MKL_jll ───────── v2022.2.0+0
#    Installed OpenBLAS32_jll ── v0.3.17+0
#    Installed SCS_jll ───────── v3.2.1+0
#    Installed SCS_GPU_jll ───── v3.2.1+0
#    Installed Requires ──────── v1.3.0
#    Installed SCS_MKL_jll ───── v3.2.2+0
#    Installed IntelOpenMP_jll ─ v2018.0.3+2
#    Installed SCS ───────────── v1.1.3
#     Updating `~/.julia/environments/v1.7/Project.toml`
#   [c946c3f1] + SCS v1.1.3
#     Updating `~/.julia/environments/v1.7/Manifest.toml`
#   [ae029012] + Requires v1.3.0
#   [c946c3f1] + SCS v1.1.3
#   [1d5cc7b8] + IntelOpenMP_jll v2018.0.3+2
#   [856f044c] + MKL_jll v2022.2.0+0
#   [656ef2d0] + OpenBLAS32_jll v0.3.17+0
#   [af6e375f] + SCS_GPU_jll v3.2.1+0
#   [3f2553a9] + SCS_MKL_jll v3.2.2+0
#   [f4f2fc5b] + SCS_jll v3.2.1+0
#   [4af54fe1] + LazyArtifacts
# Precompiling project...
#   ✓ Requires
#   ✓ IntelOpenMP_jll
#   ✓ OpenBLAS32_jll
#   ✓ MKL_jll
#   ✓ SCS_GPU_jll
#   ✓ SCS_jll
#   ✓ SCS_MKL_jll
#   ✓ SCS
#   8 dependencies successfully precompiled in 38 seconds (50 already precompiled)

# %%
function max_max_int_relax3(w, n1 ,k1 , n2, k2)

model=Model(SCS.Optimizer)

@variable(model, 0<=y[1:n2]<=1)
@variable(model, 0<=x[1:n1]<=1)
@variable(model, U[1:n1+n2+1,1:n1+n2+1],PSD)

@constraint(model, bornes[i in 1:n1+n2+1,j in 1:n1+n2+1], 0<=U[i,j]<=1)

@constraint(model,type1[i in 1:n1],U[i,n1+n2+1]==x[i])
@constraint(model,type2[j in 1:n2],U[j+n1,n1+n2+1]==y[j])

@constraint(model,U[n1+n2+1,n1+n2+1]==1)

@constraint(model,somme_j[j in 1:n2], sum(U[i,j+n1] for i in 1:n1) ==k1*y[j])
@constraint(model,somme_i[i in 1:n1], sum(U[i,j+n1] for j in 1:n2) ==k2*x[i])

@constraint(model,identify_x[i in 1:n1], U[i,i]==x[i])
@constraint(model,identify_y[j in 1:n2], U[j+n1,j+n1]==y[j])


@constraint(model,somme_x, sum(x[i] for i in 1:n1) ==k1)
@constraint(model,somme_y, sum(y[j] for j in 1:n2) ==k2)

@constraint(model,RLT3[i in 1:n1],sum(U[i,j+n1] for j in 1:n2) ==k2*x[i])
@constraint(model,RLT4[j in 1:n2],sum(U[j+n1,i] for i in 1:n1) ==k1*y[j])

@constraint(model, RLT1[i in 1:n1,j in 1:n2],U[i,j+n1]-x[i]<=0)
@constraint(model, RLT2[i in 1:n1,j in 1:n2],U[i,j+n1]-y[j]<=0)

@constraint(model,RLT5[i in 1:n1],sum(U[i,l] for l in 1:n1) ==k1*x[i])
@constraint(model,RLT6[j in 1:n2],sum(U[j+n1,l+n1] for l in 1:n2) ==k2*y[j])

@constraint(model, RLT7[i in 1:n1,l in 1:n1],U[i,l]-x[i]<=0)
@constraint(model, RLT8[l in 1:n2,j in 1:n2],U[l+n1,j+n1]-y[j]<=0)


@objective(model, Max, sum(w[i,j]*U[i,j+n1] for i in 1:n1,j in 1:n2))

print(model)

optimize!(model)

return objective_value(model)

end
max_max_int_relax3(W,Nm ,km , Na , ka)
# Out:
# $$ \begin{aligned}
# \max\quad & -4 U_{1,7} - 9 U_{1,9} - U_{1,10} - 2 U_{1,11} - 9 U_{1,12} - 4 U_{1,13} - 5 U_{1,14} - 10 U_{2,7} - U_{2,8} - 7 U_{2,9} - 5 U_{2,12} - 6 U_{2,13} - 5 U_{2,14} - 3 U_{3,7} - 9 U_{3,8} - 9 U_{3,9} - 5 U_{3,10} - 7 U_{3,12} - 3 U_{3,13} - 10 U_{3,14} - 10 U_{4,7} - 4 U_{4,9} - 10 U_{4,11} - 7 U_{4,12} - 6 U_{4,13} - 2 U_{4,14} - 9 U_{5,7} - 7 U_{5,8} - 8 U_{5,9} - U_{5,11} - 6 U_{5,12} - 5 U_{5,13} - 3 U_{6,7} - 3 U_{6,8} - 5 U_{6,9} - 10 U_{6,10} - 9 U_{6,11} - U_{6,12} - 4 U_{6,13} - 8 U_{6,14}\\
# \text{Subject to} \quad & -x_{1} + U_{1,15} = 0.0\\
#  & -x_{2} + U_{2,15} = 0.0\\
#  & -x_{3} + U_{3,15} = 0.0\\
#  & -x_{4} + U_{4,15} = 0.0\\
#  & -x_{5} + U_{5,15} = 0.0\\
#  & -x_{6} + U_{6,15} = 0.0\\
#  & -y_{1} + U_{7,15} = 0.0\\
#  & -y_{2} + U_{8,15} = 0.0\\
#  & -y_{3} + U_{9,15} = 0.0\\
#  & -y_{4} + U_{10,15} = 0.0\\
#  & -y_{5} + U_{11,15} = 0.0\\
#  & -y_{6} + U_{12,15} = 0.0\\
#  & -y_{7} + U_{13,15} = 0.0\\
#  & -y_{8} + U_{14,15} = 0.0\\
#  & U_{15,15} = 1.0\\
#  & -3 y_{1} + U_{1,7} + U_{2,7} + U_{3,7} + U_{4,7} + U_{5,7} + U_{6,7} = 0.0\\
#  & -3 y_{2} + U_{1,8} + U_{2,8} + U_{3,8} + U_{4,8} + U_{5,8} + U_{6,8} = 0.0\\
#  & -3 y_{3} + U_{1,9} + U_{2,9} + U_{3,9} + U_{4,9} + U_{5,9} + U_{6,9} = 0.0\\
#  & -3 y_{4} + U_{1,10} + U_{2,10} + U_{3,10} + U_{4,10} + U_{5,10} + U_{6,10} = 0.0\\
#  & -3 y_{5} + U_{1,11} + U_{2,11} + U_{3,11} + U_{4,11} + U_{5,11} + U_{6,11} = 0.0\\
#  & -3 y_{6} + U_{1,12} + U_{2,12} + U_{3,12} + U_{4,12} + U_{5,12} + U_{6,12} = 0.0\\
#  & -3 y_{7} + U_{1,13} + U_{2,13} + U_{3,13} + U_{4,13} + U_{5,13} + U_{6,13} = 0.0\\
#  & -3 y_{8} + U_{1,14} + U_{2,14} + U_{3,14} + U_{4,14} + U_{5,14} + U_{6,14} = 0.0\\
#  & -3 x_{1} + U_{1,7} + U_{1,8} + U_{1,9} + U_{1,10} + U_{1,11} + U_{1,12} + U_{1,13} + U_{1,14} = 0.0\\
#  & -3 x_{2} + U_{2,7} + U_{2,8} + U_{2,9} + U_{2,10} + U_{2,11} + U_{2,12} + U_{2,13} + U_{2,14} = 0.0\\
#  & -3 x_{3} + U_{3,7} + U_{3,8} + U_{3,9} + U_{3,10} + U_{3,11} + U_{3,12} + U_{3,13} + U_{3,14} = 0.0\\
#  & -3 x_{4} + U_{4,7} + U_{4,8} + U_{4,9} + U_{4,10} + U_{4,11} + U_{4,12} + U_{4,13} + U_{4,14} = 0.0\\
#  & -3 x_{5} + U_{5,7} + U_{5,8} + U_{5,9} + U_{5,10} + U_{5,11} + U_{5,12} + U_{5,13} + U_{5,14} = 0.0\\
#  & -3 x_{6} + U_{6,7} + U_{6,8} + U_{6,9} + U_{6,10} + U_{6,11} + U_{6,12} + U_{6,13} + U_{6,14} = 0.0\\
#  & -x_{1} + U_{1,1} = 0.0\\
#  & -x_{2} + U_{2,2} = 0.0\\
#  & -x_{3} + U_{3,3} = 0.0\\
#  & -x_{4} + U_{4,4} = 0.0\\
#  & -x_{5} + U_{5,5} = 0.0\\
#  & -x_{6} + U_{6,6} = 0.0\\
#  & -y_{1} + U_{7,7} = 0.0\\
#  & -y_{2} + U_{8,8} = 0.0\\
#  & -y_{3} + U_{9,9} = 0.0\\
#  & -y_{4} + U_{10,10} = 0.0\\
#  & -y_{5} + U_{11,11} = 0.0\\
#  & -y_{6} + U_{12,12} = 0.0\\
#  & -y_{7} + U_{13,13} = 0.0\\
#  & -y_{8} + U_{14,14} = 0.0\\
#  & x_{1} + x_{2} + x_{3} + x_{4} + x_{5} + x_{6} = 3.0\\
#  & y_{1} + y_{2} + y_{3} + y_{4} + y_{5} + y_{6} + y_{7} + y_{8} = 3.0\\
#  & -3 x_{1} + U_{1,7} + U_{1,8} + U_{1,9} + U_{1,10} + U_{1,11} + U_{1,12} + U_{1,13} + U_{1,14} = 0.0\\
#  & -3 x_{2} + U_{2,7} + U_{2,8} + U_{2,9} + U_{2,10} + U_{2,11} + U_{2,12} + U_{2,13} + U_{2,14} = 0.0\\
#  & -3 x_{3} + U_{3,7} + U_{3,8} + U_{3,9} + U_{3,10} + U_{3,11} + U_{3,12} + U_{3,13} + U_{3,14} = 0.0\\
#  & -3 x_{4} + U_{4,7} + U_{4,8} + U_{4,9} + U_{4,10} + U_{4,11} + U_{4,12} + U_{4,13} + U_{4,14} = 0.0\\
#  & -3 x_{5} + U_{5,7} + U_{5,8} + U_{5,9} + U_{5,10} + U_{5,11} + U_{5,12} + U_{5,13} + U_{5,14} = 0.0\\
#  & -3 x_{6} + U_{6,7} + U_{6,8} + U_{6,9} + U_{6,10} + U_{6,11} + U_{6,12} + U_{6,13} + U_{6,14} = 0.0\\
#  & -3 y_{1} + U_{1,7} + U_{2,7} + U_{3,7} + U_{4,7} + U_{5,7} + U_{6,7} = 0.0\\
#  & -3 y_{2} + U_{1,8} + U_{2,8} + U_{3,8} + U_{4,8} + U_{5,8} + U_{6,8} = 0.0\\
#  & -3 y_{3} + U_{1,9} + U_{2,9} + U_{3,9} + U_{4,9} + U_{5,9} + U_{6,9} = 0.0\\
#  & -3 y_{4} + U_{1,10} + U_{2,10} + U_{3,10} + U_{4,10} + U_{5,10} + U_{6,10} = 0.0\\
#  & -3 y_{5} + U_{1,11} + U_{2,11} + U_{3,11} + U_{4,11} + U_{5,11} + U_{6,11} = 0.0\\
#  & -3 y_{6} + U_{1,12} + U_{2,12} + U_{3,12} + U_{4,12} + U_{5,12} + U_{6,12} = 0.0\\
#  & -3 y_{7} + U_{1,13} + U_{2,13} + U_{3,13} + U_{4,13} + U_{5,13} + U_{6,13} = 0.0\\
#  & -3 y_{8} + U_{1,14} + U_{2,14} + U_{3,14} + U_{4,14} + U_{5,14} + U_{6,14} = 0.0\\
#  & -3 x_{1} + U_{1,1} + U_{1,2} + U_{1,3} + U_{1,4} + U_{1,5} + U_{1,6} = 0.0\\
#  & -3 x_{2} + U_{1,2} + U_{2,2} + U_{2,3} + U_{2,4} + U_{2,5} + U_{2,6} = 0.0\\
#  & -3 x_{3} + U_{1,3} + U_{2,3} + U_{3,3} + U_{3,4} + U_{3,5} + U_{3,6} = 0.0\\
#  & -3 x_{4} + U_{1,4} + U_{2,4} + U_{3,4} + U_{4,4} + U_{4,5} + U_{4,6} = 0.0\\
#  & -3 x_{5} + U_{1,5} + U_{2,5} + U_{3,5} + U_{4,5} + U_{5,5} + U_{5,6} = 0.0\\
#  & -3 x_{6} + U_{1,6} + U_{2,6} + U_{3,6} + U_{4,6} + U_{5,6} + U_{6,6} = 0.0\\
#  & -3 y_{1} + U_{7,7} + U_{7,8} + U_{7,9} + U_{7,10} + U_{7,11} + U_{7,12} + U_{7,13} + U_{7,14} = 0.0\\
#  & -3 y_{2} + U_{7,8} + U_{8,8} + U_{8,9} + U_{8,10} + U_{8,11} + U_{8,12} + U_{8,13} + U_{8,14} = 0.0\\
#  & -3 y_{3} + U_{7,9} + U_{8,9} + U_{9,9} + U_{9,10} + U_{9,11} + U_{9,12} + U_{9,13} + U_{9,14} = 0.0\\
#  & -3 y_{4} + U_{7,10} + U_{8,10} + U_{9,10} + U_{10,10} + U_{10,11} + U_{10,12} + U_{10,13} + U_{10,14} = 0.0\\
#  & -3 y_{5} + U_{7,11} + U_{8,11} + U_{9,11} + U_{10,11} + U_{11,11} + U_{11,12} + U_{11,13} + U_{11,14} = 0.0\\
#  & -3 y_{6} + U_{7,12} + U_{8,12} + U_{9,12} + U_{10,12} + U_{11,12} + U_{12,12} + U_{12,13} + U_{12,14} = 0.0\\
#  & -3 y_{7} + U_{7,13} + U_{8,13} + U_{9,13} + U_{10,13} + U_{11,13} + U_{12,13} + U_{13,13} + U_{13,14} = 0.0\\
#  & -3 y_{8} + U_{7,14} + U_{8,14} + U_{9,14} + U_{10,14} + U_{11,14} + U_{12,14} + U_{13,14} + U_{14,14} = 0.0\\
#  & -x_{1} + U_{1,7} \leq 0.0\\
#  & -x_{2} + U_{2,7} \leq 0.0\\
#  & -x_{3} + U_{3,7} \leq 0.0\\
#  & -x_{4} + U_{4,7} \leq 0.0\\
#  & -x_{5} + U_{5,7} \leq 0.0\\
#  & -x_{6} + U_{6,7} \leq 0.0\\
#  & -x_{1} + U_{1,8} \leq 0.0\\
#  & -x_{2} + U_{2,8} \leq 0.0\\
#  & -x_{3} + U_{3,8} \leq 0.0\\
#  & -x_{4} + U_{4,8} \leq 0.0\\
#  & -x_{5} + U_{5,8} \leq 0.0\\
#  & -x_{6} + U_{6,8} \leq 0.0\\
#  & -x_{1} + U_{1,9} \leq 0.0\\
#  & -x_{2} + U_{2,9} \leq 0.0\\
#  & -x_{3} + U_{3,9} \leq 0.0\\
#  & -x_{4} + U_{4,9} \leq 0.0\\
#  & -x_{5} + U_{5,9} \leq 0.0\\
#  & -x_{6} + U_{6,9} \leq 0.0\\
#  & -x_{1} + U_{1,10} \leq 0.0\\
#  & -x_{2} + U_{2,10} \leq 0.0\\
#  & -x_{3} + U_{3,10} \leq 0.0\\
#  & -x_{4} + U_{4,10} \leq 0.0\\
#  & -x_{5} + U_{5,10} \leq 0.0\\
#  & -x_{6} + U_{6,10} \leq 0.0\\
#  & -x_{1} + U_{1,11} \leq 0.0\\
#  & -x_{2} + U_{2,11} \leq 0.0\\
#  & -x_{3} + U_{3,11} \leq 0.0\\
#  & -x_{4} + U_{4,11} \leq 0.0\\
#  & -x_{5} + U_{5,11} \leq 0.0\\
#  & -x_{6} + U_{6,11} \leq 0.0\\
#  & -x_{1} + U_{1,12} \leq 0.0\\
#  & -x_{2} + U_{2,12} \leq 0.0\\
#  & -x_{3} + U_{3,12} \leq 0.0\\
#  & -x_{4} + U_{4,12} \leq 0.0\\
#  & -x_{5} + U_{5,12} \leq 0.0\\
#  & -x_{6} + U_{6,12} \leq 0.0\\
#  & -x_{1} + U_{1,13} \leq 0.0\\
#  & -x_{2} + U_{2,13} \leq 0.0\\
#  & -x_{3} + U_{3,13} \leq 0.0\\
#  & -x_{4} + U_{4,13} \leq 0.0\\
#  & -x_{5} + U_{5,13} \leq 0.0\\
#  & -x_{6} + U_{6,13} \leq 0.0\\
#  & -x_{1} + U_{1,14} \leq 0.0\\
#  & -x_{2} + U_{2,14} \leq 0.0\\
#  & -x_{3} + U_{3,14} \leq 0.0\\
#  & -x_{4} + U_{4,14} \leq 0.0\\
#  & -x_{5} + U_{5,14} \leq 0.0\\
#  & -x_{6} + U_{6,14} \leq 0.0\\
#  & -y_{1} + U_{1,7} \leq 0.0\\
#  & -y_{1} + U_{2,7} \leq 0.0\\
#  & -y_{1} + U_{3,7} \leq 0.0\\
#  & -y_{1} + U_{4,7} \leq 0.0\\
#  & -y_{1} + U_{5,7} \leq 0.0\\
#  & -y_{1} + U_{6,7} \leq 0.0\\
#  & -y_{2} + U_{1,8} \leq 0.0\\
#  & -y_{2} + U_{2,8} \leq 0.0\\
#  & -y_{2} + U_{3,8} \leq 0.0\\
#  & -y_{2} + U_{4,8} \leq 0.0\\
#  & -y_{2} + U_{5,8} \leq 0.0\\
#  & -y_{2} + U_{6,8} \leq 0.0\\
#  & -y_{3} + U_{1,9} \leq 0.0\\
#  & -y_{3} + U_{2,9} \leq 0.0\\
#  & -y_{3} + U_{3,9} \leq 0.0\\
#  & -y_{3} + U_{4,9} \leq 0.0\\
#  & -y_{3} + U_{5,9} \leq 0.0\\
#  & -y_{3} + U_{6,9} \leq 0.0\\
#  & -y_{4} + U_{1,10} \leq 0.0\\
#  & -y_{4} + U_{2,10} \leq 0.0\\
#  & -y_{4} + U_{3,10} \leq 0.0\\
#  & -y_{4} + U_{4,10} \leq 0.0\\
#  & -y_{4} + U_{5,10} \leq 0.0\\
#  & -y_{4} + U_{6,10} \leq 0.0\\
#  & -y_{5} + U_{1,11} \leq 0.0\\
#  & -y_{5} + U_{2,11} \leq 0.0\\
#  & -y_{5} + U_{3,11} \leq 0.0\\
#  & -y_{5} + U_{4,11} \leq 0.0\\
#  & -y_{5} + U_{5,11} \leq 0.0\\
#  & -y_{5} + U_{6,11} \leq 0.0\\
#  & -y_{6} + U_{1,12} \leq 0.0\\
#  & -y_{6} + U_{2,12} \leq 0.0\\
#  & -y_{6} + U_{3,12} \leq 0.0\\
#  & -y_{6} + U_{4,12} \leq 0.0\\
#  & -y_{6} + U_{5,12} \leq 0.0\\
#  & -y_{6} + U_{6,12} \leq 0.0\\
#  & -y_{7} + U_{1,13} \leq 0.0\\
#  & -y_{7} + U_{2,13} \leq 0.0\\
#  & -y_{7} + U_{3,13} \leq 0.0\\
#  & -y_{7} + U_{4,13} \leq 0.0\\
#  & -y_{7} + U_{5,13} \leq 0.0\\
#  & -y_{7} + U_{6,13} \leq 0.0\\
#  & -y_{8} + U_{1,14} \leq 0.0\\
#  & -y_{8} + U_{2,14} \leq 0.0\\
#  & -y_{8} + U_{3,14} \leq 0.0\\
#  & -y_{8} + U_{4,14} \leq 0.0\\
#  & -y_{8} + U_{5,14} \leq 0.0\\
#  & -y_{8} + U_{6,14} \leq 0.0\\
#  & -x_{1} + U_{1,1} \leq 0.0\\
#  & -x_{2} + U_{1,2} \leq 0.0\\
#  & -x_{3} + U_{1,3} \leq 0.0\\
#  & -x_{4} + U_{1,4} \leq 0.0\\
#  & -x_{5} + U_{1,5} \leq 0.0\\
#  & -x_{6} + U_{1,6} \leq 0.0\\
#  & -x_{1} + U_{1,2} \leq 0.0\\
#  & -x_{2} + U_{2,2} \leq 0.0\\
#  & -x_{3} + U_{2,3} \leq 0.0\\
#  & -x_{4} + U_{2,4} \leq 0.0\\
#  & -x_{5} + U_{2,5} \leq 0.0\\
#  & -x_{6} + U_{2,6} \leq 0.0\\
#  & -x_{1} + U_{1,3} \leq 0.0\\
#  & -x_{2} + U_{2,3} \leq 0.0\\
#  & -x_{3} + U_{3,3} \leq 0.0\\
#  & -x_{4} + U_{3,4} \leq 0.0\\
#  & -x_{5} + U_{3,5} \leq 0.0\\
#  & -x_{6} + U_{3,6} \leq 0.0\\
#  & -x_{1} + U_{1,4} \leq 0.0\\
#  & -x_{2} + U_{2,4} \leq 0.0\\
#  & -x_{3} + U_{3,4} \leq 0.0\\
#  & -x_{4} + U_{4,4} \leq 0.0\\
#  & -x_{5} + U_{4,5} \leq 0.0\\
#  & -x_{6} + U_{4,6} \leq 0.0\\
#  & -x_{1} + U_{1,5} \leq 0.0\\
#  & -x_{2} + U_{2,5} \leq 0.0\\
#  & -x_{3} + U_{3,5} \leq 0.0\\
#  & -x_{4} + U_{4,5} \leq 0.0\\
#  & -x_{5} + U_{5,5} \leq 0.0\\
#  & -x_{6} + U_{5,6} \leq 0.0\\
#  & -x_{1} + U_{1,6} \leq 0.0\\
#  & -x_{2} + U_{2,6} \leq 0.0\\
#  & -x_{3} + U_{3,6} \leq 0.0\\
#  & -x_{4} + U_{4,6} \leq 0.0\\
#  & -x_{5} + U_{5,6} \leq 0.0\\
#  & -x_{6} + U_{6,6} \leq 0.0\\
#  & -y_{1} + U_{7,7} \leq 0.0\\
#  & -y_{1} + U_{7,8} \leq 0.0\\
#  & -y_{1} + U_{7,9} \leq 0.0\\
#  & -y_{1} + U_{7,10} \leq 0.0\\
#  & -y_{1} + U_{7,11} \leq 0.0\\
#  & -y_{1} + U_{7,12} \leq 0.0\\
#  & -y_{1} + U_{7,13} \leq 0.0\\
#  & -y_{1} + U_{7,14} \leq 0.0\\
#  & -y_{2} + U_{7,8} \leq 0.0\\
#  & -y_{2} + U_{8,8} \leq 0.0\\
#  & -y_{2} + U_{8,9} \leq 0.0\\
#  & -y_{2} + U_{8,10} \leq 0.0\\
#  & -y_{2} + U_{8,11} \leq 0.0\\
#  & -y_{2} + U_{8,12} \leq 0.0\\
#  & -y_{2} + U_{8,13} \leq 0.0\\
#  & -y_{2} + U_{8,14} \leq 0.0\\
#  & -y_{3} + U_{7,9} \leq 0.0\\
#  & -y_{3} + U_{8,9} \leq 0.0\\
#  & -y_{3} + U_{9,9} \leq 0.0\\
#  & -y_{3} + U_{9,10} \leq 0.0\\
#  & -y_{3} + U_{9,11} \leq 0.0\\
#  & -y_{3} + U_{9,12} \leq 0.0\\
#  & -y_{3} + U_{9,13} \leq 0.0\\
#  & -y_{3} + U_{9,14} \leq 0.0\\
#  & -y_{4} + U_{7,10} \leq 0.0\\
#  & -y_{4} + U_{8,10} \leq 0.0\\
#  & -y_{4} + U_{9,10} \leq 0.0\\
#  & -y_{4} + U_{10,10} \leq 0.0\\
#  & -y_{4} + U_{10,11} \leq 0.0\\
#  & -y_{4} + U_{10,12} \leq 0.0\\
#  & -y_{4} + U_{10,13} \leq 0.0\\
#  & -y_{4} + U_{10,14} \leq 0.0\\
#  & -y_{5} + U_{7,11} \leq 0.0\\
#  & -y_{5} + U_{8,11} \leq 0.0\\
#  & -y_{5} + U_{9,11} \leq 0.0\\
#  & -y_{5} + U_{10,11} \leq 0.0\\
#  & -y_{5} + U_{11,11} \leq 0.0\\
#  & -y_{5} + U_{11,12} \leq 0.0\\
#  & -y_{5} + U_{11,13} \leq 0.0\\
#  & -y_{5} + U_{11,14} \leq 0.0\\
#  & -y_{6} + U_{7,12} \leq 0.0\\
#  & -y_{6} + U_{8,12} \leq 0.0\\
#  & -y_{6} + U_{9,12} \leq 0.0\\
#  & -y_{6} + U_{10,12} \leq 0.0\\
#  & -y_{6} + U_{11,12} \leq 0.0\\
#  & -y_{6} + U_{12,12} \leq 0.0\\
#  & -y_{6} + U_{12,13} \leq 0.0\\
#  & -y_{6} + U_{12,14} \leq 0.0\\
#  & -y_{7} + U_{7,13} \leq 0.0\\
#  & -y_{7} + U_{8,13} \leq 0.0\\
#  & -y_{7} + U_{9,13} \leq 0.0\\
#  & -y_{7} + U_{10,13} \leq 0.0\\
#  & -y_{7} + U_{11,13} \leq 0.0\\
#  & -y_{7} + U_{12,13} \leq 0.0\\
#  & -y_{7} + U_{13,13} \leq 0.0\\
#  & -y_{7} + U_{13,14} \leq 0.0\\
#  & -y_{8} + U_{7,14} \leq 0.0\\
#  & -y_{8} + U_{8,14} \leq 0.0\\
#  & -y_{8} + U_{9,14} \leq 0.0\\
#  & -y_{8} + U_{10,14} \leq 0.0\\
#  & -y_{8} + U_{11,14} \leq 0.0\\
#  & -y_{8} + U_{12,14} \leq 0.0\\
#  & -y_{8} + U_{13,14} \leq 0.0\\
#  & -y_{8} + U_{14,14} \leq 0.0\\
#  & U_{1,1} \in \[0.0, 1.0\]\\
#  & U_{1,2} \in \[0.0, 1.0\]\\
#  & U_{1,3} \in \[0.0, 1.0\]\\
#  & U_{1,4} \in \[0.0, 1.0\]\\
#  & U_{1,5} \in \[0.0, 1.0\]\\
#  & U_{1,6} \in \[0.0, 1.0\]\\
#  & U_{1,7} \in \[0.0, 1.0\]\\
#  & U_{1,8} \in \[0.0, 1.0\]\\
#  & U_{1,9} \in \[0.0, 1.0\]\\
#  & U_{1,10} \in \[0.0, 1.0\]\\
#  & U_{1,11} \in \[0.0, 1.0\]\\
#  & U_{1,12} \in \[0.0, 1.0\]\\
#  & U_{1,13} \in \[0.0, 1.0\]\\
#  & U_{1,14} \in \[0.0, 1.0\]\\
#  & U_{1,15} \in \[0.0, 1.0\]\\
#  & U_{1,2} \in \[0.0, 1.0\]\\
#  & U_{2,2} \in \[0.0, 1.0\]\\
#  & U_{2,3} \in \[0.0, 1.0\]\\
#  & U_{2,4} \in \[0.0, 1.0\]\\
#  & U_{2,5} \in \[0.0, 1.0\]\\
#  & U_{2,6} \in \[0.0, 1.0\]\\
#  & U_{2,7} \in \[0.0, 1.0\]\\
#  & U_{2,8} \in \[0.0, 1.0\]\\
#  & U_{2,9} \in \[0.0, 1.0\]\\
#  & U_{2,10} \in \[0.0, 1.0\]\\
#  & U_{2,11} \in \[0.0, 1.0\]\\
#  & U_{2,12} \in \[0.0, 1.0\]\\
#  & U_{2,13} \in \[0.0, 1.0\]\\
#  & U_{2,14} \in \[0.0, 1.0\]\\
#  & U_{2,15} \in \[0.0, 1.0\]\\
#  & U_{1,3} \in \[0.0, 1.0\]\\
#  & U_{2,3} \in \[0.0, 1.0\]\\
#  & U_{3,3} \in \[0.0, 1.0\]\\
#  & U_{3,4} \in \[0.0, 1.0\]\\
#  & U_{3,5} \in \[0.0, 1.0\]\\
#  & U_{3,6} \in \[0.0, 1.0\]\\
#  & U_{3,7} \in \[0.0, 1.0\]\\
#  & U_{3,8} \in \[0.0, 1.0\]\\
#  & U_{3,9} \in \[0.0, 1.0\]\\
#  & U_{3,10} \in \[0.0, 1.0\]\\
#  & U_{3,11} \in \[0.0, 1.0\]\\
#  & U_{3,12} \in \[0.0, 1.0\]\\
#  & U_{3,13} \in \[0.0, 1.0\]\\
#  & U_{3,14} \in \[0.0, 1.0\]\\
#  & U_{3,15} \in \[0.0, 1.0\]\\
#  & U_{1,4} \in \[0.0, 1.0\]\\
#  & U_{2,4} \in \[0.0, 1.0\]\\
#  & U_{3,4} \in \[0.0, 1.0\]\\
#  & U_{4,4} \in \[0.0, 1.0\]\\
#  & U_{4,5} \in \[0.0, 1.0\]\\
#  & U_{4,6} \in \[0.0, 1.0\]\\
#  & U_{4,7} \in \[0.0, 1.0\]\\
#  & U_{4,8} \in \[0.0, 1.0\]\\
#  & U_{4,9} \in \[0.0, 1.0\]\\
#  & U_{4,10} \in \[0.0, 1.0\]\\
#  & U_{4,11} \in \[0.0, 1.0\]\\
#  & U_{4,12} \in \[0.0, 1.0\]\\
#  & U_{4,13} \in \[0.0, 1.0\]\\
#  & U_{4,14} \in \[0.0, 1.0\]\\
#  & U_{4,15} \in \[0.0, 1.0\]\\
#  & U_{1,5} \in \[0.0, 1.0\]\\
#  & U_{2,5} \in \[0.0, 1.0\]\\
#  & U_{3,5} \in \[0.0, 1.0\]\\
#  & U_{4,5} \in \[0.0, 1.0\]\\
#  & U_{5,5} \in \[0.0, 1.0\]\\
#  & U_{5,6} \in \[0.0, 1.0\]\\
#  & U_{5,7} \in \[0.0, 1.0\]\\
#  & U_{5,8} \in \[0.0, 1.0\]\\
#  & U_{5,9} \in \[0.0, 1.0\]\\
#  & U_{5,10} \in \[0.0, 1.0\]\\
#  & U_{5,11} \in \[0.0, 1.0\]\\
#  & U_{5,12} \in \[0.0, 1.0\]\\
#  & U_{5,13} \in \[0.0, 1.0\]\\
#  & U_{5,14} \in \[0.0, 1.0\]\\
#  & U_{5,15} \in \[0.0, 1.0\]\\
#  & U_{1,6} \in \[0.0, 1.0\]\\
#  & U_{2,6} \in \[0.0, 1.0\]\\
#  & U_{3,6} \in \[0.0, 1.0\]\\
#  & U_{4,6} \in \[0.0, 1.0\]\\
#  & U_{5,6} \in \[0.0, 1.0\]\\
#  & U_{6,6} \in \[0.0, 1.0\]\\
#  & U_{6,7} \in \[0.0, 1.0\]\\
#  & U_{6,8} \in \[0.0, 1.0\]\\
#  & U_{6,9} \in \[0.0, 1.0\]\\
#  & U_{6,10} \in \[0.0, 1.0\]\\
#  & U_{6,11} \in \[0.0, 1.0\]\\
#  & U_{6,12} \in \[0.0, 1.0\]\\
#  & U_{6,13} \in \[0.0, 1.0\]\\
#  & U_{6,14} \in \[0.0, 1.0\]\\
#  & U_{6,15} \in \[0.0, 1.0\]\\
#  & U_{1,7} \in \[0.0, 1.0\]\\
#  & U_{2,7} \in \[0.0, 1.0\]\\
#  & U_{3,7} \in \[0.0, 1.0\]\\
#  & U_{4,7} \in \[0.0, 1.0\]\\
#  & U_{5,7} \in \[0.0, 1.0\]\\
#  & U_{6,7} \in \[0.0, 1.0\]\\
#  & U_{7,7} \in \[0.0, 1.0\]\\
#  & U_{7,8} \in \[0.0, 1.0\]\\
#  & U_{7,9} \in \[0.0, 1.0\]\\
#  & U_{7,10} \in \[0.0, 1.0\]\\
#  & U_{7,11} \in \[0.0, 1.0\]\\
#  & U_{7,12} \in \[0.0, 1.0\]\\
#  & U_{7,13} \in \[0.0, 1.0\]\\
#  & U_{7,14} \in \[0.0, 1.0\]\\
#  & U_{7,15} \in \[0.0, 1.0\]\\
#  & U_{1,8} \in \[0.0, 1.0\]\\
#  & U_{2,8} \in \[0.0, 1.0\]\\
#  & U_{3,8} \in \[0.0, 1.0\]\\
#  & U_{4,8} \in \[0.0, 1.0\]\\
#  & U_{5,8} \in \[0.0, 1.0\]\\
#  & U_{6,8} \in \[0.0, 1.0\]\\
#  & U_{7,8} \in \[0.0, 1.0\]\\
#  & U_{8,8} \in \[0.0, 1.0\]\\
#  & U_{8,9} \in \[0.0, 1.0\]\\
#  & U_{8,10} \in \[0.0, 1.0\]\\
#  & U_{8,11} \in \[0.0, 1.0\]\\
#  & U_{8,12} \in \[0.0, 1.0\]\\
#  & U_{8,13} \in \[0.0, 1.0\]\\
#  & U_{8,14} \in \[0.0, 1.0\]\\
#  & U_{8,15} \in \[0.0, 1.0\]\\
#  & U_{1,9} \in \[0.0, 1.0\]\\
#  & U_{2,9} \in \[0.0, 1.0\]\\
#  & U_{3,9} \in \[0.0, 1.0\]\\
#  & U_{4,9} \in \[0.0, 1.0\]\\
#  & U_{5,9} \in \[0.0, 1.0\]\\
#  & U_{6,9} \in \[0.0, 1.0\]\\
#  & U_{7,9} \in \[0.0, 1.0\]\\
#  & U_{8,9} \in \[0.0, 1.0\]\\
#  & U_{9,9} \in \[0.0, 1.0\]\\
#  & U_{9,10} \in \[0.0, 1.0\]\\
#  & U_{9,11} \in \[0.0, 1.0\]\\
#  & U_{9,12} \in \[0.0, 1.0\]\\
#  & U_{9,13} \in \[0.0, 1.0\]\\
#  & U_{9,14} \in \[0.0, 1.0\]\\
#  & U_{9,15} \in \[0.0, 1.0\]\\
#  & U_{1,10} \in \[0.0, 1.0\]\\
#  & U_{2,10} \in \[0.0, 1.0\]\\
#  & U_{3,10} \in \[0.0, 1.0\]\\
#  & U_{4,10} \in \[0.0, 1.0\]\\
#  & U_{5,10} \in \[0.0, 1.0\]\\
#  & U_{6,10} \in \[0.0, 1.0\]\\
#  & U_{7,10} \in \[0.0, 1.0\]\\
#  & U_{8,10} \in \[0.0, 1.0\]\\
#  & U_{9,10} \in \[0.0, 1.0\]\\
#  & U_{10,10} \in \[0.0, 1.0\]\\
#  & U_{10,11} \in \[0.0, 1.0\]\\
#  & U_{10,12} \in \[0.0, 1.0\]\\
#  & U_{10,13} \in \[0.0, 1.0\]\\
#  & U_{10,14} \in \[0.0, 1.0\]\\
#  & U_{10,15} \in \[0.0, 1.0\]\\
#  & U_{1,11} \in \[0.0, 1.0\]\\
#  & U_{2,11} \in \[0.0, 1.0\]\\
#  & U_{3,11} \in \[0.0, 1.0\]\\
#  & U_{4,11} \in \[0.0, 1.0\]\\
#  & U_{5,11} \in \[0.0, 1.0\]\\
#  & U_{6,11} \in \[0.0, 1.0\]\\
#  & U_{7,11} \in \[0.0, 1.0\]\\
#  & U_{8,11} \in \[0.0, 1.0\]\\
#  & U_{9,11} \in \[0.0, 1.0\]\\
#  & U_{10,11} \in \[0.0, 1.0\]\\
#  & U_{11,11} \in \[0.0, 1.0\]\\
#  & U_{11,12} \in \[0.0, 1.0\]\\
#  & U_{11,13} \in \[0.0, 1.0\]\\
#  & U_{11,14} \in \[0.0, 1.0\]\\
#  & U_{11,15} \in \[0.0, 1.0\]\\
#  & U_{1,12} \in \[0.0, 1.0\]\\
#  & U_{2,12} \in \[0.0, 1.0\]\\
#  & U_{3,12} \in \[0.0, 1.0\]\\
#  & U_{4,12} \in \[0.0, 1.0\]\\
#  & U_{5,12} \in \[0.0, 1.0\]\\
#  & U_{6,12} \in \[0.0, 1.0\]\\
#  & U_{7,12} \in \[0.0, 1.0\]\\
#  & U_{8,12} \in \[0.0, 1.0\]\\
#  & U_{9,12} \in \[0.0, 1.0\]\\
#  & U_{10,12} \in \[0.0, 1.0\]\\
#  & U_{11,12} \in \[0.0, 1.0\]\\
#  & U_{12,12} \in \[0.0, 1.0\]\\
#  & U_{12,13} \in \[0.0, 1.0\]\\
#  & U_{12,14} \in \[0.0, 1.0\]\\
#  & U_{12,15} \in \[0.0, 1.0\]\\
#  & U_{1,13} \in \[0.0, 1.0\]\\
#  & U_{2,13} \in \[0.0, 1.0\]\\
#  & U_{3,13} \in \[0.0, 1.0\]\\
#  & U_{4,13} \in \[0.0, 1.0\]\\
#  & U_{5,13} \in \[0.0, 1.0\]\\
#  & U_{6,13} \in \[0.0, 1.0\]\\
#  & U_{7,13} \in \[0.0, 1.0\]\\
#  & U_{8,13} \in \[0.0, 1.0\]\\
#  & U_{9,13} \in \[0.0, 1.0\]\\
#  & U_{10,13} \in \[0.0, 1.0\]\\
#  & U_{11,13} \in \[0.0, 1.0\]\\
#  & U_{12,13} \in \[0.0, 1.0\]\\
#  & U_{13,13} \in \[0.0, 1.0\]\\
#  & U_{13,14} \in \[0.0, 1.0\]\\
#  & U_{13,15} \in \[0.0, 1.0\]\\
#  & U_{1,14} \in \[0.0, 1.0\]\\
#  & U_{2,14} \in \[0.0, 1.0\]\\
#  & U_{3,14} \in \[0.0, 1.0\]\\
#  & U_{4,14} \in \[0.0, 1.0\]\\
#  & U_{5,14} \in \[0.0, 1.0\]\\
#  & U_{6,14} \in \[0.0, 1.0\]\\
#  & U_{7,14} \in \[0.0, 1.0\]\\
#  & U_{8,14} \in \[0.0, 1.0\]\\
#  & U_{9,14} \in \[0.0, 1.0\]\\
#  & U_{10,14} \in \[0.0, 1.0\]\\
#  & U_{11,14} \in \[0.0, 1.0\]\\
#  & U_{12,14} \in \[0.0, 1.0\]\\
#  & U_{13,14} \in \[0.0, 1.0\]\\
#  & U_{14,14} \in \[0.0, 1.0\]\\
#  & U_{14,15} \in \[0.0, 1.0\]\\
#  & U_{1,15} \in \[0.0, 1.0\]\\
#  & U_{2,15} \in \[0.0, 1.0\]\\
#  & U_{3,15} \in \[0.0, 1.0\]\\
#  & U_{4,15} \in \[0.0, 1.0\]\\
#  & U_{5,15} \in \[0.0, 1.0\]\\
#  & U_{6,15} \in \[0.0, 1.0\]\\
#  & U_{7,15} \in \[0.0, 1.0\]\\
#  & U_{8,15} \in \[0.0, 1.0\]\\
#  & U_{9,15} \in \[0.0, 1.0\]\\
#  & U_{10,15} \in \[0.0, 1.0\]\\
#  & U_{11,15} \in \[0.0, 1.0\]\\
#  & U_{12,15} \in \[0.0, 1.0\]\\
#  & U_{13,15} \in \[0.0, 1.0\]\\
#  & U_{14,15} \in \[0.0, 1.0\]\\
#  & U_{15,15} \in \[0.0, 1.0\]\\
#  & [U_{1,1}, U_{1,2}, U_{2,2}, U_{1,3}, U_{2,3}, U_{3,3}, U_{1,4}, U_{2,4}, U_{3,4}, U_{4,4}, U_{1,5}, U_{2,5}, U_{3,5}, U_{4,5}, U_{5,5}, U_{1,6}, U_{2,6}, U_{3,6}, U_{4,6}, U_{5,6}, U_{6,6}, U_{1,7}, U_{2,7}, U_{3,7}, U_{4,7}, U_{5,7}, U_{6,7}, U_{7,7}, U_{1,8}, U_{2,8}, U_{3,8}, U_{4,8}, U_{5,8}, U_{6,8}, U_{7,8}, U_{8,8}, U_{1,9}, U_{2,9}, U_{3,9}, U_{4,9}, U_{5,9}, U_{6,9}, U_{7,9}, U_{8,9}, U_{9,9}, U_{1,10}, U_{2,10}, U_{3,10}, U_{4,10}, U_{5,10}, U_{6,10}, U_{7,10}, U_{8,10}, U_{9,10}, U_{10,10}, U_{1,11}, U_{2,11}, U_{3,11}, U_{4,11}, U_{5,11}, U_{6,11}, U_{7,11}, U_{8,11}, U_{9,11}, U_{10,11}, U_{11,11}, U_{1,12}, U_{2,12}, U_{3,12}, U_{4,12}, U_{5,12}, U_{6,12}, U_{7,12}, U_{8,12}, U_{9,12}, U_{10,12}, U_{11,12}, U_{12,12}, U_{1,13}, U_{2,13}, U_{3,13}, U_{4,13}, U_{5,13}, U_{6,13}, U_{7,13}, U_{8,13}, U_{9,13}, U_{10,13}, U_{11,13}, U_{12,13}, U_{13,13}, U_{1,14}, U_{2,14}, U_{3,14}, U_{4,14}, U_{5,14}, U_{6,14}, U_{7,14}, U_{8,14}, U_{9,14}, U_{10,14}, U_{11,14}, U_{12,14}, U_{13,14}, U_{14,14}, U_{1,15}, U_{2,15}, U_{3,15}, U_{4,15}, U_{5,15}, U_{6,15}, U_{7,15}, U_{8,15}, U_{9,15}, U_{10,15}, U_{11,15}, U_{12,15}, U_{13,15}, U_{14,15}, U_{15,15}] \in \text{MathOptInterface.PositiveSemidefiniteConeTriangle(15)}\\
#  & y_{1} \geq 0.0\\
#  & y_{2} \geq 0.0\\
#  & y_{3} \geq 0.0\\
#  & y_{4} \geq 0.0\\
#  & y_{5} \geq 0.0\\
#  & y_{6} \geq 0.0\\
#  & y_{7} \geq 0.0\\
#  & y_{8} \geq 0.0\\
#  & x_{1} \geq 0.0\\
#  & x_{2} \geq 0.0\\
#  & x_{3} \geq 0.0\\
#  & x_{4} \geq 0.0\\
#  & x_{5} \geq 0.0\\
#  & x_{6} \geq 0.0\\
#  & y_{1} \leq 1.0\\
#  & y_{2} \leq 1.0\\
#  & y_{3} \leq 1.0\\
#  & y_{4} \leq 1.0\\
#  & y_{5} \leq 1.0\\
#  & y_{6} \leq 1.0\\
#  & y_{7} \leq 1.0\\
#  & y_{8} \leq 1.0\\
#  & x_{1} \leq 1.0\\
#  & x_{2} \leq 1.0\\
#  & x_{3} \leq 1.0\\
#  & x_{4} \leq 1.0\\
#  & x_{5} \leq 1.0\\
#  & x_{6} \leq 1.0\\
# \end{aligned} $$
# ------------------------------------------------------------------
# 	       SCS v3.2.1 - Splitting Conic Solver
# 	(c) Brendan O'Donoghue, Stanford University, 2012
# ------------------------------------------------------------------
# problem:  variables n: 134, constraints m: 867
# cones: 	  z: primal zero / dual free vars: 73
# 	  l: linear vars: 674
# 	  s: psd vars: 120, ssize: 1
# settings: eps_abs: 1.0e-04, eps_rel: 1.0e-04, eps_infeas: 1.0e-07
# 	  alpha: 1.50, scale: 1.00e-01, adaptive_scale: 1
# 	  max_iters: 100000, normalize: 1, rho_x: 1.00e-06
# 	  acceleration_lookback: 10, acceleration_interval: 10
# lin-sys:  sparse-direct-amd-qdldl
# 	  nnz(A): 1395, nnz(P): 0
# ------------------------------------------------------------------
#  iter | pri res | dua res |   gap   |   obj   |  scale  | time (s)
# ------------------------------------------------------------------
#      0| 1.27e+01  6.35e+00  9.97e+02 -4.44e+02  1.00e-01  1.85e-03
#    250| 8.89e-03  2.35e-03  2.56e-02  1.12e+01  4.30e-01  3.07e-02
#    500| 2.62e-03  3.69e-03  2.13e-02  1.13e+01  1.40e+00  5.99e-02
#    750| 4.06e-04  3.56e-04  8.69e-04  1.13e+01  1.40e+00  8.82e-02
#    775| 3.43e-04  3.06e-04  7.20e-04  1.13e+01  1.40e+00  9.10e-02
# ------------------------------------------------------------------
# status:  solved
# timings: total: 9.10e-02s = setup: 1.38e-03s + solve: 8.97e-02s
# 	 lin-sys: 1.85e-02s, cones: 6.14e-02s, accel: 7.95e-04s
# ------------------------------------------------------------------
# objective = 11.287599
# ------------------------------------------------------------------
# -11.287239556348114

# %% [markdown]
# Implémentez la fonction max_max_int_relax3 et montrez la validité de la relaxation sous-jacente. On voit que l'optimum obtenu n'est pas loin de l'optimum entier (max_max_int). Essayons encore de nous en rapprocher.

# %% [markdown]
# ## Question 11
#
# Quand on cherche à linéariser le produit de variables binaires (par exemple $U_{i,l} = x_i \times x_l$), on peut rajouter l'inégalité valide $U_{i, l} \geq x_i + x_l - 1$.  En rajoutant ce type de contraintes, nous obtenons une nouvelle relaxation qui est légèrement meilleure.
#
# Modifiez donc la fonction précédente pour résoudre la nouvelle relaxation (définissez une nouvelle fonction function max_max_int_relax4(w, n1 ,k1 , n2, k2) qui intègre les nouvelles contraintes ainsi que celle déjà considérées dans function max_max_int_rela3...)
#
# Résolvez... Quel est l'optimum de la relaxation ?

# %% [markdown]
# ## Question 12
#    Faites  varier les tailles de l'instance et générer des instances aléatorires  (par exemple, à l'aide de la commande W = float(rand(-10:0,Nm,Na))). Observez le gap des 4 relaxations et les temps de calcul de max_min_int comparé à celui de chacune des 4 relaxations  (on pourra par exemple utiliser la commande   time = @elapsed max_max_int_relax4(W,Nm ,km , Na , ka)  pour mesurer le temps pris pour résoudre la quatrième relaxation).
